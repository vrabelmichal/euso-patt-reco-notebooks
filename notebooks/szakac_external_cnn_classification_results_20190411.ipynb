# %%
import sys
import os

import pandas as pd

app_base_dir = '/home/spbproc/euso-spb-patt-reco-v1'
if app_base_dir not in sys.path:
    sys.path.append(app_base_dir)

import event_processing_v3
import event_processing_v4
import postgresql_v3_event_storage
import dataset_query_functions_v3

# %%
classifiaction_tables_dir = 'szakac_external_cnn_classification_results_20190411'
data_snippets_dir = 'szakac_external_cnn_classification_results_20190411'

os.makedirs(data_snippets_dir, exist_ok=True)

# %%
event_v3_storage_provider_flight = dataset_query_functions_v3.build_event_v3_storage_provider(
    event_storage_provider_config_file=os.path.join(app_base_dir,'config_w_flatmap.ini'), 
    table_names_version='ver4',
    event_storage_class=postgresql_v3_event_storage.PostgreSqlEventV3StorageProvider,
    event_processing_class=event_processing_v4.EventProcessingV4,
    readonly=False
)

query_functions_flight = dataset_query_functions_v3.Ver3DatasetQueryFunctions(event_v3_storage_provider_flight)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## tnet 30000

# %%
tnet_30000_df = pd.read_csv(os.path.join(classifiaction_tables_dir,'tnet_30000.tsv'), sep='\t')

# %%
len(tnet_30000_df)

# %%
tnet_30000_df.head()
# Out:
#         event_id  class  class_probablility
# 0             75      1                 1.0
# 1            250      1                 1.0
# 2            356      1                 1.0
# 3            686      1                 1.0
# 4            791      1                 1.0
# 5            907      1                 1.0
# 6            913      1                 1.0
# 7           1048      1                 1.0
# 8           1279      1                 1.0
# 9           1448      1                 1.0
# 10          1708      1                 1.0
# 11          1840      1                 1.0
# 12          2039      1                 1.0
# 13          2105      1                 1.0
# 14          2217      1                 1.0
# 15          2375      1                 1.0
# 16          2432      1                 1.0
# 17          2493      1                 1.0
# 18          2610      1                 1.0
# 19          2631      1                 1.0
# ...

# %%
classification_slug_tnet_30000 = 'cnn_tnet_30000_20190411'

# %%
classification_columns = (('event_id', int), ('class', int), ('class_probability', float))

# %%
event_v3_storage_provider_flight.create_classification_table(classification_slug_tnet_30000, classification_columns)

# %%
event_v3_storage_provider_flight.save_classification_data(
    classification_slug_tnet_30000, tnet_30000_df.values, 
    classification_columns, num_inserts_at_once=1000)

# %%
#event_v3_storage_provider_flight.connection.reset()

# %% [markdown]
# ## tnet 45000

# %%
tnet_45000_df = pd.read_csv(os.path.join(classifiaction_tables_dir,'tnet_45000.tsv'), sep='\t')

# %%
len(tnet_45000_df)
# Out:
# 109301

# %%
tnet_45000_df.head()
# Out:
#    event_id  class  class_probablility
# 0       134      1                 1.0
# 1       443      1                 1.0
# 2       465      1                 1.0
# 3       676      1                 1.0
# 4       736      1                 1.0

# %%
classification_slug_tnet_45000 = 'cnn_tnet_45000_20190411'

# %%
# classification_columns remain

# %%
event_v3_storage_provider_flight.connection.reset()

# %%
event_v3_storage_provider_flight.create_classification_table(classification_slug_tnet_45000, classification_columns)

# %%
event_v3_storage_provider_flight.save_classification_data(
    classification_slug_tnet_45000, tnet_45000_df.values, 
    classification_columns, num_inserts_at_once=1000)

# %% [markdown]
# ## tnet common events

# %%
tnet_common_df = pd.read_csv(os.path.join(classifiaction_tables_dir,'common_event_id.tsv'), sep='\t')

# %%
len(tnet_common_df)
# Out:
# 209

# %%
tnet_common_df.head()
# Out:
#    a.event_id
# 0         913
# 1        1279
# 2        2610
# 3        3884
# 4       11511

# %%
classification_slug_tnet_common = 'cnn_tnet_common_20190411'

# %%
# classification_columns remain

# %%
# event_v3_storage_provider_flight.create_classification_table(classification_slug_tnet_common, classification_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-d41de13ec6eb> in <module>()
# ----> 1 event_v3_storage_provider_flight.create_classification_table(classification_slug_tnet_common, classification_columns)
#
# NameError: name 'classification_slug_tnet_common' is not defined

# %%
# event_v3_storage_provider_flight.save_classification_data(
#     classification_slug_tnet_45000, tnet_45000_df.values, 
#     classification_columns, num_inserts_at_once=1000)
