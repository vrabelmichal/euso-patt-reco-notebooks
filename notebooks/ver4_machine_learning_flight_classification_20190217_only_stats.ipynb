# %%
import sys
import os
import subprocess
import re
import numpy as np
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as psql
import getpass
import matplotlib as mpl
import argparse
import glob
import traceback
import hashlib
import math
import collections
import functools

import sklearn.preprocessing
import sklearn.feature_selection
import sklearn.ensemble 
import sklearn.neural_network
import sklearn.model_selection
import sklearn.metrics
import sklearn.pipeline
from sklearn.externals import joblib

mpl.rcParams['figure.dpi'] = 80

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /home/vrabel/EUSO-Balloon/vrabel/venv/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
app_base_dir = '/home/spbproc/euso-spb-patt-reco-v1'
if app_base_dir not in sys.path:
    sys.path.append(app_base_dir)

import event_processing_v3
import event_processing_v4
import postgresql_v3_event_storage
import dataset_query_functions_v3

import tool.acqconv
from data_analysis_utils import *
from data_analysis_utils_dataframes import *
from data_analysis_utils_trigger_rate import *
# import supervised_classification as supc
# Out:
# Welcome to JupyROOT 6.13/02

# %%
inverse_means_map = np.load('/home/spbproc/euso-spb-patt-reco-v1/resources/inverse_flat_average_directions_4m_flipud.npy')

# %%
model_data_snippets_dir = 'ver4_machine_learning_w_labeled_flight_20190217'
data_snippets_dir = 'ver4_machine_learning_flight_classification_tsne_cfg3_20190217'

os.makedirs(data_snippets_dir, exist_ok=True)

# %%
subset_classification_slug = 'ver4_ml_tsne_cfg3_201904217'

# %% [markdown]
# # Selecting the flight data

# %%
event_processing_cls = event_processing_v4.EventProcessingV4
event_v3_storage_provider_flight = dataset_query_functions_v3.build_event_v3_storage_provider(
    event_storage_provider_config_file=os.path.join(app_base_dir,'config_w_flatmap.ini'), 
    table_names_version='ver4',
    event_storage_class=postgresql_v3_event_storage.PostgreSqlEventV3StorageProvider,
    event_processing_class=event_processing_cls,
    readonly=False
)

query_functions_flight = dataset_query_functions_v3.Ver3DatasetQueryFunctions(event_v3_storage_provider_flight)

# %% [markdown]
# ## Columns

# %%
rfecv_selector_on_extra_trees__column_names = []

columns_list_file_pathname = os.path.join(model_data_snippets_dir, 'rfecv_selector_on_extra_trees__column_names.txt')
print(columns_list_file_pathname)
with open(columns_list_file_pathname, 'r') as columns_list_file:
    rfecv_selector_on_extra_trees__column_names = columns_list_file.read().splitlines()
# Out:
# ver4_machine_learning_w_labeled_flight_20190217/rfecv_selector_on_extra_trees__column_names.txt

# %%
rfecv_selector_on_extra_trees__column_names__special = []

special_columns_list_file_pathname = os.path.join(model_data_snippets_dir, 'rfecv_selector_on_extra_trees__column_names__special.txt')
print(special_columns_list_file_pathname)
with open(special_columns_list_file_pathname, 'r') as special_columns_list_file:
    rfecv_selector_on_extra_trees__column_names__special = special_columns_list_file.read().splitlines()
# Out:
# ver4_machine_learning_w_labeled_flight_20190217/rfecv_selector_on_extra_trees__column_names__special.txt

# %%
# This should be empty for now
rfecv_selector_on_extra_trees__column_names__special
# Out:
# []

# %%
flight_columns_for_analysis_dict = query_functions_flight.get_columns_for_classification_dict__by_excluding(
    excluded_columns_re_list=('^.+$',),
    default_excluded_columns_re_list=[],
    included_columns_re_list=[
        ('^$','source_file_(acquisition|trigger)(_full)?|global_gtu|packet_id|gtu_in_packet|event_id|num_gtu'),
        ('gps_datetime_min')
    ] + rfecv_selector_on_extra_trees__column_names
)

classification_flight_columns_for_analysis_dict = query_functions_flight.get_columns_for_classification_dict__by_excluding(
    excluded_columns_re_list=('^.+$',),
    default_excluded_columns_re_list=[],
    included_columns_re_list=rfecv_selector_on_extra_trees__column_names
)

print_columns_dict(flight_columns_for_analysis_dict)
# Out:
# spb_processing_v4_flatmap.event
# 	- event_id
# 	- source_file_acquisition_full
# 	- source_file_trigger_full
# 	- source_file_acquisition
# 	- source_file_trigger
# 	- global_gtu
# 	- packet_id
# 	- gtu_in_packet
# 	- num_gtu
#
# spb_processing_v4_flatmap.event_trg_box_per_gtu
# 	- max
# 	- sum
# 	- mean
# 	- mean_gz
#
# spb_processing_v4_flatmap.event_trg_pmt_per_gtu
# 	- sum
# 	- mean
# 	- mean_gz
#
# spb_processing_v4_flatmap.event_trg_ec_per_gtu
# 	- sum
# 	- mean
# 	- mean_gz
#
# spb_processing_v4_flatmap.event_gps_datetime
# 	- min
#
# spb_processing_v4_flatmap.event_trg_x_y_clusters
# 	- sizes_min
# 	- sizes_max
# 	- clu_areas_max
# 	- max_size_clu_width
# 	- max_size_clu_height
# 	- max_peak_clu_width
# 	- max_peak_clu_height
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_trg_gtu_x_clusters
# 	- sizes_min
# 	- sizes_max
# 	- max_size_clu_height
# 	- max_peak_clu_height
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_trg_gtu_y_clusters
# 	- sizes_min
# 	- sizes_max
# 	- max_size_clu_height
# 	- max_peak_clu_height
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_orig_x_y
# 	- count_nonzero
# 	- max
#
# spb_processing_v4_flatmap.event_proc1_x_y_clusters
# 	- sizes_min
# 	- sizes_max
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc2_x_y_clusters
# 	- count
# 	- sizes_min
# 	- sizes_max
# 	- clu_areas_max
# 	- max_peak_clu_width
# 	- max_peak_clu_height
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc3_x_y_clusters
# 	- sizes_max
# 	- clu_areas_max
# 	- max_size_clu_height
# 	- max_peak_clu_width
# 	- max_peak_clu_height
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc1_gtu_x_clusters
# 	- sizes_min
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc2_gtu_x_clusters
# 	- sizes_min
# 	- sizes_max
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc3_gtu_x_clusters
# 	- sizes_max
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc1_gtu_y_clusters
# 	- sizes_min
# 	- sizes_max
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc2_gtu_y_clusters
# 	- sizes_min
# 	- sizes_max
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_proc3_gtu_y_clusters
# 	- sizes_max
# 	- max_peak_clu_width
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_bg_x_y
# 	- count_nonzero
# 	- sum
# 	- mean
# 	- mean_gz
#
# spb_processing_v4_flatmap.event_alt1_gtu_x_clusters
# 	- sizes_max
# 	- max_peak_clu_size
#
# spb_processing_v4_flatmap.event_trg
# 	- count_nonzero
# 	- max
# 	- mean
# 	- mean_gz
#
# spb_processing_v4_flatmap.event_bg
# 	- count_nonzero
# 	- sum
# 	- mean
# 	- mean_gz
# 	- size
#
# spb_processing_v4_flatmap.event_orig
# 	- mean
# 	- mean_gz
#
# spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1
# 	- major_line_rho
# 	- line_clusters_clu_widths_max
# 	- line_clusters_clu_heights_max
# 	- line_clusters_clu_areas_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_area_clu_height
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_size_clu_height
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_sum_clu_height
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_peak_clu_height
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2
# 	- major_line_rho
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_peak_clu_height
#
# spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr3
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1
# 	- major_line_rho
# 	- line_clusters_clu_widths_max
# 	- line_clusters_clu_areas_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_area_clu_height
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_size_clu_height
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_sum_clu_height
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_peak_clu_height
#
# spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr2
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr3
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_peak_clu_width
#
# spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1
# 	- major_line_phi
# 	- line_clusters_count
# 	- line_clusters_sizes_max
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_area_clu_height
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_size_clu_height
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_sum_clu_height
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_peak_clu_height
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2
# 	- major_line_phi
# 	- major_line_rho
# 	- line_clusters_count
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_sum_clu_width
#
# spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr3
# 	- major_line_phi
# 	- major_line_rho
# 	- line_clusters_count
#
# spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1
# 	- major_line_phi
# 	- major_line_rho
# 	- line_clusters_count
# 	- line_clusters_sizes_max
# 	- line_clusters_clu_widths_max
# 	- line_clusters_clu_heights_max
# 	- line_clusters_clu_areas_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_area_clu_height
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_sum_clu_height
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2
# 	- major_line_phi
# 	- major_line_rho
# 	- line_clusters_count
# 	- line_clusters_clu_heights_max
#
# spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3
# 	- major_line_coord_0_x
# 	- major_line_coord_0_y
# 	- major_line_coord_1_x
# 	- major_line_phi
# 	- major_line_rho
# 	- line_clusters_count
# 	- line_clusters_clu_heights_max
#
# spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1
# 	- major_line_phi
# 	- line_clusters_count
# 	- line_clusters_sizes_max
# 	- line_clusters_clu_widths_max
# 	- line_clusters_clu_heights_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_area_clu_height
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr2
# 	- major_line_phi
# 	- line_clusters_count
# 	- line_clusters_clu_heights_max
#
# spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr3
# 	- major_line_coord_1_x
# 	- line_clusters_count
# 	- line_clusters_clu_heights_max
#
# spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr1
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr2
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr3
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr1
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr2
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr3
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr1
# 	- line_clusters_count
#
# spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr2
# 	- line_clusters_count
#
# spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1
# 	- line_clusters_sizes_max
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1
# 	- line_clusters_count
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_size_clu_width
#
# spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr2
# 	- line_clusters_count
#
# spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1
# 	- major_line_phi
# 	- line_clusters_count
# 	- line_clusters_sizes_max
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_area_clu_height
# 	- line_clusters_max_size_clu_width
# 	- line_clusters_max_size_clu_height
# 	- line_clusters_max_sum_clu_width
# 	- line_clusters_max_sum_clu_height
# 	- line_clusters_max_peak_clu_width
# 	- line_clusters_max_peak_clu_height
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2
# 	- major_line_phi
# 	- line_clusters_count
# 	- line_clusters_clu_widths_max
# 	- line_clusters_max_area_clu_width
# 	- line_clusters_max_size_clu_width
#
# spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr3
# 	- major_line_phi
#
# spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr1
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr2
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr3
# 	- major_line_rho
#
# spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1
# 	- major_line_rho
# 	- line_clusters_sizes_max
# 	- line_clusters_max_area_clu_size
# 	- line_clusters_max_peak_clu_size
# 	- line_clusters_max_sum_clu_size
#
# ------------------------------------------------------------
# 248

# %% [markdown]
# WARNING: not selecting NULL trg lines

# %% [markdown]
# ## Event classes

# %%
EVENT_CLASSES = {
    'dot': 2,
    'top_left_ec': 5,
    'blob': 12,
    'large_blob': 11,
    'short_single_gtu_track': 7,
    'single_gtu_track': 3,
    'noise': 1,
    'cartesian_line': 4,
    'strong_pmt_edge': 9,
    'few_dots': 6,
    'bg_increased_suddenly': 10,
    'persistent_dot': 14,
    'noise_unspecified': 0,
    'unspecified': 8,
    'shower': 13,
    '2pix_line': 15,
    'bright_blob': 16,
    'blob_and_dots': 17,
    'dot_w_blob_behind': 18,
    'storng_light': 19,
    'sparse_blobs': 20,
    'noise_with_week_dot': 21,
    #
    'unclassified': -1
}

# %%
len(EVENT_CLASSES)
# Out:
# 23

# %%
INVERSE_EVENT_CLASSES = {v: k for k, v in EVENT_CLASSES.items()}

# %% [markdown]
# ## Constructing the query

# %%
classification_table_name = event_v3_storage_provider_flight.database_schema_name + '.event_manual_classification'

current_columns_for_analysis_dict = flight_columns_for_analysis_dict

flight_select_clause_str, flight_tables_list = \
    query_functions_flight.get_query_clauses__select({
    **current_columns_for_analysis_dict,
    classification_table_name: ['class_number']
})

flight_clauses_str = \
    query_functions_flight.get_query_clauses__join(flight_tables_list)

flight_source_data_type_num = 1

flight_where_clauses_str = ''' 
    AND abs(gtu_in_packet-42) < 20
    AND {database_schema_name}.event_orig_x_y.count_nonzero > 256*6
'''

for table, cols_list in classification_flight_columns_for_analysis_dict.items():
    for col in cols_list:
        flight_where_clauses_str += ' AND {}.{} IS NOT NULL\n'.format(table, col)

flight_events_selection_query = query_functions_flight.get_events_selection_query_plain(
    source_data_type_num=flight_source_data_type_num,
    select_additional=flight_select_clause_str, 
    join_additional=flight_clauses_str,
    where_additional=flight_where_clauses_str,
    order_by='{data_table_name}.event_id', 
    offset=0, limit=350000,
    base_select='')

# %%
print(flight_events_selection_query)
# Out:
#     SELECT
#
#         spb_processing_v4_flatmap.event.event_id, spb_processing_v4_flatmap.event.source_file_acquisition_full, spb_processing_v4_flatmap.event.source_file_trigger_full, spb_processing_v4_flatmap.event.source_file_acquisition, spb_processing_v4_flatmap.event.source_file_trigger, spb_processing_v4_flatmap.event.global_gtu, spb_processing_v4_flatmap.event.packet_id, spb_processing_v4_flatmap.event.gtu_in_packet, spb_processing_v4_flatmap.event.num_gtu, spb_processing_v4_flatmap.event_trg_box_per_gtu.max AS trg_box_per_gtu_max, spb_processing_v4_flatmap.event_trg_box_per_gtu.sum AS trg_box_per_gtu_sum, spb_processing_v4_flatmap.event_trg_box_per_gtu.mean AS trg_box_per_gtu_mean, spb_processing_v4_flatmap.event_trg_box_per_gtu.mean_gz AS trg_box_per_gtu_mean_gz, spb_processing_v4_flatmap.event_trg_pmt_per_gtu.sum AS trg_pmt_per_gtu_sum, spb_processing_v4_flatmap.event_trg_pmt_per_gtu.mean AS trg_pmt_per_gtu_mean, spb_processing_v4_flatmap.event_trg_pmt_per_gtu.mean_gz AS trg_pmt_per_gtu_mean_gz, spb_processing_v4_flatmap.event_trg_ec_per_gtu.sum AS trg_ec_per_gtu_sum, spb_processing_v4_flatmap.event_trg_ec_per_gtu.mean AS trg_ec_per_gtu_mean, spb_processing_v4_flatmap.event_trg_ec_per_gtu.mean_gz AS trg_ec_per_gtu_mean_gz, spb_processing_v4_flatmap.event_gps_datetime.min AS gps_datetime_min, spb_processing_v4_flatmap.event_trg_x_y_clusters.sizes_min AS trg_x_y_clusters_sizes_min, spb_processing_v4_flatmap.event_trg_x_y_clusters.sizes_max AS trg_x_y_clusters_sizes_max, spb_processing_v4_flatmap.event_trg_x_y_clusters.clu_areas_max AS trg_x_y_clusters_clu_areas_max, spb_processing_v4_flatmap.event_trg_x_y_clusters.max_size_clu_width AS trg_x_y_clusters_max_size_clu_width, spb_processing_v4_flatmap.event_trg_x_y_clusters.max_size_clu_height AS trg_x_y_clusters_max_size_clu_height, spb_processing_v4_flatmap.event_trg_x_y_clusters.max_peak_clu_width AS trg_x_y_clusters_max_peak_clu_width, spb_processing_v4_flatmap.event_trg_x_y_clusters.max_peak_clu_height AS trg_x_y_clusters_max_peak_clu_height, spb_processing_v4_flatmap.event_trg_x_y_clusters.max_peak_clu_size AS trg_x_y_clusters_max_peak_clu_size, spb_processing_v4_flatmap.event_trg_gtu_x_clusters.sizes_min AS trg_gtu_x_clusters_sizes_min, spb_processing_v4_flatmap.event_trg_gtu_x_clusters.sizes_max AS trg_gtu_x_clusters_sizes_max, spb_processing_v4_flatmap.event_trg_gtu_x_clusters.max_size_clu_height AS trg_gtu_x_clusters_max_size_clu_height, spb_processing_v4_flatmap.event_trg_gtu_x_clusters.max_peak_clu_height AS trg_gtu_x_clusters_max_peak_clu_height, spb_processing_v4_flatmap.event_trg_gtu_x_clusters.max_peak_clu_size AS trg_gtu_x_clusters_max_peak_clu_size, spb_processing_v4_flatmap.event_trg_gtu_y_clusters.sizes_min AS trg_gtu_y_clusters_sizes_min, spb_processing_v4_flatmap.event_trg_gtu_y_clusters.sizes_max AS trg_gtu_y_clusters_sizes_max, spb_processing_v4_flatmap.event_trg_gtu_y_clusters.max_size_clu_height AS trg_gtu_y_clusters_max_size_clu_height, spb_processing_v4_flatmap.event_trg_gtu_y_clusters.max_peak_clu_height AS trg_gtu_y_clusters_max_peak_clu_height, spb_processing_v4_flatmap.event_trg_gtu_y_clusters.max_peak_clu_size AS trg_gtu_y_clusters_max_peak_clu_size, spb_processing_v4_flatmap.event_orig_x_y.count_nonzero AS orig_x_y_count_nonzero, spb_processing_v4_flatmap.event_orig_x_y.max AS orig_x_y_max, spb_processing_v4_flatmap.event_proc1_x_y_clusters.sizes_min AS proc1_x_y_clusters_sizes_min, spb_processing_v4_flatmap.event_proc1_x_y_clusters.sizes_max AS proc1_x_y_clusters_sizes_max, spb_processing_v4_flatmap.event_proc1_x_y_clusters.max_peak_clu_size AS proc1_x_y_clusters_max_peak_clu_size, spb_processing_v4_flatmap.event_proc2_x_y_clusters.count AS proc2_x_y_clusters_count, spb_processing_v4_flatmap.event_proc2_x_y_clusters.sizes_min AS proc2_x_y_clusters_sizes_min, spb_processing_v4_flatmap.event_proc2_x_y_clusters.sizes_max AS proc2_x_y_clusters_sizes_max, spb_processing_v4_flatmap.event_proc2_x_y_clusters.clu_areas_max AS proc2_x_y_clusters_clu_areas_max, s ...
#      FROM spb_processing_v4_flatmap.event
#
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_box_per_gtu ON (spb_processing_v4_flatmap.event_trg_box_per_gtu.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_pmt_per_gtu ON (spb_processing_v4_flatmap.event_trg_pmt_per_gtu.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_ec_per_gtu ON (spb_processing_v4_flatmap.event_trg_ec_per_gtu.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_gps_datetime ON (spb_processing_v4_flatmap.event_gps_datetime.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_x_y_clusters ON (spb_processing_v4_flatmap.event_trg_x_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_gtu_x_clusters ON (spb_processing_v4_flatmap.event_trg_gtu_x_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_gtu_y_clusters ON (spb_processing_v4_flatmap.event_trg_gtu_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_orig_x_y ON (spb_processing_v4_flatmap.event_orig_x_y.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_x_y_clusters ON (spb_processing_v4_flatmap.event_proc1_x_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_x_y_clusters ON (spb_processing_v4_flatmap.event_proc2_x_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_x_y_clusters ON (spb_processing_v4_flatmap.event_proc3_x_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_gtu_x_clusters ON (spb_processing_v4_flatmap.event_proc1_gtu_x_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_gtu_x_clusters ON (spb_processing_v4_flatmap.event_proc2_gtu_x_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_gtu_x_clusters ON (spb_processing_v4_flatmap.event_proc3_gtu_x_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_gtu_y_clusters ON (spb_processing_v4_flatmap.event_proc1_gtu_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_gtu_y_clusters ON (spb_processing_v4_flatmap.event_proc2_gtu_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_gtu_y_clusters ON (spb_processing_v4_flatmap.event_proc3_gtu_y_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_bg_x_y ON (spb_processing_v4_flatmap.event_bg_x_y.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_gtu_x_clusters ON (spb_processing_v4_flatmap.event_alt1_gtu_x_clusters.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg ON (spb_processing_v4_flatmap.event_trg.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_bg ON (spb_processing_v4_flatmap.event_bg.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_orig ON (spb_processing_v4_flatmap.event_orig.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr2 ON (spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr2.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr3 ON (spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr3.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1 ON (spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1.event_id = spb_processing_v4_flatmap.event.event_id)
#   LEFT JOIN spb_processing_v4_flatmap.event_manual_classification ON (spb_processing_v4_flatmap.event_manual_classification.event_id = spb_processing_v4_flatmap.event.event_id)
#     WHERE
#         source_data_type_num = 1
#
#     AND abs(gtu_in_packet-42) < 20
#     AND spb_processing_v4_flatmap.event_orig_x_y.count_nonzero > 256*6
#  AND spb_processing_v4_flatmap.event_trg_box_per_gtu.max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_box_per_gtu.sum IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_box_per_gtu.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_box_per_gtu.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_pmt_per_gtu.sum IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_pmt_per_gtu.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_pmt_per_gtu.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_ec_per_gtu.sum IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_ec_per_gtu.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_ec_per_gtu.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.clu_areas_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_clusters.max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_clusters.max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_clusters.max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_clusters.max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_orig_x_y.count_nonzero IS NOT NULL
#  AND spb_processing_v4_flatmap.event_orig_x_y.max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.clu_areas_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_clusters.clu_areas_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_clusters.max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_clusters.max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_clusters.max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_x_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_x_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_x_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_x_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_x_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_x_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_x_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_y_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_clusters.sizes_min IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_clusters.max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg_x_y.count_nonzero IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg_x_y.sum IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg_x_y.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg_x_y.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_x_clusters.sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_x_clusters.max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg.count_nonzero IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg.max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg.count_nonzero IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg.sum IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_bg.size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_orig.mean IS NOT NULL
#  AND spb_processing_v4_flatmap.event_orig.mean_gz IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_clu_areas_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_area_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_sum_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr2.line_clusters_max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_x_y_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_clu_areas_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_area_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_sum_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr1.line_clusters_max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_x_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_trg_gtu_y_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_area_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_sum_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr2.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr3.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_x_y_hough_peak_thr3.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_clu_areas_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_area_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_sum_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr2.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.major_line_coord_0_x IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.major_line_coord_0_y IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.major_line_coord_1_x IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_x_y_hough_peak_thr3.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_area_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr2.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr2.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr2.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr3.major_line_coord_1_x IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr3.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_x_y_hough_peak_thr3.line_clusters_clu_heights_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc1_gtu_x_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_x_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr1.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_x_hough_peak_thr2.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.line_clusters_sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc2_gtu_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_proc3_gtu_y_hough_peak_thr2.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_area_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_size_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_sum_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_sum_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_peak_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_peak_clu_height IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2.line_clusters_count IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2.line_clusters_clu_widths_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2.line_clusters_max_area_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr2.line_clusters_max_size_clu_width IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_x_y_hough_peak_thr3.major_line_phi IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr2.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_x_hough_peak_thr3.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1.major_line_rho IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1.line_clusters_sizes_max IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1.line_clusters_max_area_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1.line_clusters_max_peak_clu_size IS NOT NULL
#  AND spb_processing_v4_flatmap.event_alt1_gtu_y_hough_peak_thr1.line_clusters_max_sum_clu_size IS NOT NULL
#
#     ORDER BY spb_processing_v4_flatmap.event.event_id
#     OFFSET 0 LIMIT 350000

# %%
flight_df = psql.read_sql(flight_events_selection_query, event_v3_storage_provider_flight.connection)

# %%
manual_classification_class_number_column = 'manual_classification_class_number'

# %%
flight_df.loc[flight_df[manual_classification_class_number_column].isnull(), 
              manual_classification_class_number_column] = -1

# %%
len(flight_df)
# Out:
# 109301

# %%
manual_classification_class_name_column = 'manual_classification_class_name'

# %%
flight_df[manual_classification_class_name_column] = 'unclassified'
for class_name, class_number in EVENT_CLASSES.items():
    flight_df.loc[flight_df[manual_classification_class_number_column]==class_number, 
                  manual_classification_class_name_column] = class_name

# %%
flight_df.head()
# Out:
#    event_id                       source_file_acquisition_full  \
# 0        61  /home/spbproc/SPBDATA_flight/allpackets-SPBEUS...
# 1        67  /home/spbproc/SPBDATA_flight/allpackets-SPBEUS...
# 2        73  /home/spbproc/SPBDATA_flight/allpackets-SPBEUS...
# 3        75  /home/spbproc/SPBDATA_flight/allpackets-SPBEUS...
# 4        77  /home/spbproc/SPBDATA_flight/allpackets-SPBEUS...
#
#                             source_file_trigger_full  \
# 0  /home/spbproc/SPBDATA_processed/allpackets-SPB...
# 1  /home/spbproc/SPBDATA_processed/allpackets-SPB...
# 2  /home/spbproc/SPBDATA_processed/allpackets-SPB...
# 3  /home/spbproc/SPBDATA_processed/allpackets-SPB...
# 4  /home/spbproc/SPBDATA_processed/allpackets-SPB...
#
#                              source_file_acquisition  \
# 0  allpackets-SPBEUSO-ACQUISITION-20170429-055842...
# 1  allpackets-SPBEUSO-ACQUISITION-20170429-055842...
# 2  allpackets-SPBEUSO-ACQUISITION-20170501-050224...
# 3  allpackets-SPBEUSO-ACQUISITION-20170501-050224...
# 4  allpackets-SPBEUSO-ACQUISITION-20170430-072445...
#
#                                  source_file_trigger  global_gtu  packet_id  \
# 0  trn_20170429-055842-001.001_C_inverse_flat_ave...          39          0
# 1  trn_20170429-055842-001.001_C_inverse_flat_ave...         166          1
# 2  trn_20170501-050224-001.001_C_inverse_flat_ave...          39          0
# 3  trn_20170501-050224-001.001_C_inverse_flat_ave...         162          1
# 4  trn_20170430-072445-001.001_C_inverse_flat_ave...          38          0
#
#    gtu_in_packet  num_gtu  trg_box_per_gtu_max  \
# 0             39       11                  7.0
# 1             38       11                  7.0
# 2             39       22                  7.0
# 3             34       15                526.0
# 4             38       33                668.0
#
#                 ...                 alt1_gtu_x_hough_peak_thr1_major_line_rho  \
# 0               ...                                                   4.74049
# 1               ...                                                   2.31214
# 2               ...                                                   2.44340
# 3               ...                                                   9.05172
# 4               ...                                                  16.28690
#
#    alt1_gtu_x_hough_peak_thr2_major_line_rho  \
# 0                                    4.60184
# 1                                    1.70155
# 2                                    5.69936
# 3                                    8.84120
# 4                                   15.53590
#
#    alt1_gtu_x_hough_peak_thr3_major_line_rho  \
# 0                                    5.41446
# 1                                    2.29509
# 2                                    5.69849
# 3                                    8.84120
# 4                                   13.86160
#
#    alt1_gtu_y_hough_peak_thr1_major_line_rho  \
# 0                                    5.14926
# 1                                    3.20554
# 2                                    1.11428
# 3                                    9.34996
# 4                                   16.24120
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_sizes_max  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    manual_classification_class_number manual_classification_class_name
# 0                                -1.0                     unclassified
# 1                                -1.0                     unclassified
# 2                                -1.0                     unclassified
# 3                                -1.0                     unclassified
# 4                                -1.0                     unclassified
#
# [5 rows x 250 columns]

# %%
flight_df[rfecv_selector_on_extra_trees__column_names].head()
# Out:
#    trg_box_per_gtu_max  trg_box_per_gtu_sum  trg_box_per_gtu_mean  \
# 0                  7.0                  9.0              0.818182
# 1                  7.0                 15.0              1.363640
# 2                  7.0                 22.0              1.000000
# 3                526.0               1012.0             67.466700
# 4                668.0               8379.0            253.909000
#
#    trg_pmt_per_gtu_sum  trg_pmt_per_gtu_mean  trg_ec_per_gtu_sum  \
# 0                  3.0              0.272727                 3.0
# 1                  4.0              0.363636                 3.0
# 2                 10.0              0.454545                10.0
# 3                 68.0              4.533330                20.0
# 4                638.0             19.333300               200.0
#
#    trg_ec_per_gtu_mean  trg_x_y_clusters_sizes_min  \
# 0             0.272727                           1
# 1             0.272727                           7
# 2             0.454545                          16
# 3             1.333330                         592
# 4             6.060610                         940
#
#    trg_x_y_clusters_sizes_max  trg_x_y_clusters_clu_areas_max  \
# 0                           7                               9
# 1                           7                              42
# 2                          16                             126
# 3                         592                            2116
# 4                         940                            2116
#
#                              ...                              \
# 0                            ...
# 1                            ...
# 2                            ...
# 3                            ...
# 4                            ...
#
#    alt1_x_y_hough_peak_thr2_line_clusters_max_size_clu_width  \
# 0                                                  4
# 1                                                 15
# 2                                                 41
# 3                                                  3
# 4                                                 20
#
#    alt1_x_y_hough_peak_thr3_major_line_phi  \
# 0                                 1.448210
# 1                                 1.290240
# 2                                 0.195124
# 3                                 1.580070
# 4                                 0.582123
#
#    alt1_gtu_x_hough_peak_thr1_major_line_rho  \
# 0                                    4.74049
# 1                                    2.31214
# 2                                    2.44340
# 3                                    9.05172
# 4                                   16.28690
#
#    alt1_gtu_x_hough_peak_thr2_major_line_rho  \
# 0                                    4.60184
# 1                                    1.70155
# 2                                    5.69936
# 3                                    8.84120
# 4                                   15.53590
#
#    alt1_gtu_x_hough_peak_thr3_major_line_rho  \
# 0                                    5.41446
# 1                                    2.29509
# 2                                    5.69849
# 3                                    8.84120
# 4                                   13.86160
#
#    alt1_gtu_y_hough_peak_thr1_major_line_rho  \
# 0                                    5.14926
# 1                                    3.20554
# 2                                    1.11428
# 3                                    9.34996
# 4                                   16.24120
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_sizes_max  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_size
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
# [5 rows x 232 columns]

# %%
np.count_nonzero(flight_df['event_id'].isnull())
# Out:
# 0

# %%
flight_df['had_nan_fields'] = flight_df[rfecv_selector_on_extra_trees__column_names].isnull().any(axis=1)

# %%
np.count_nonzero(flight_df['had_nan_fields'])
# Out:
# 0

# %%
flight_df_nonan = flight_df[~flight_df['had_nan_fields']]

# %%
len(flight_df_nonan)
# Out:
# 109301

# %%
# TODO
# SELECT COUNT(*) FROM spb_processing_v4_flatmap.event JOIN spb_processing_v4_flatmap.event_orig_x_y USING(event_id) WHERE source_data_type_num = 1 AND abs(gtu_in_packet-42) < 20 AND spb_processing_v4_flatmap.event_orig_x_y.count_nonzero > 256*6 LIMIT 5;
# SELECT COUNT( DISTINCT (source_file_acquisition, packet_id)) FROM spb_processing_v4_flatmap.event JOIN spb_processing_v4_flatmap.event_orig_x_y USING(event_id) WHERE source_data_type_num = 1 AND abs(gtu_in_packet-42) < 20 AND spb_processing_v4_flatmap.event_orig_x_y.count_nonzero > 256*6 LIMIT 5;

# %%
cur = event_v3_storage_provider_flight.connection.cursor()

# %%
cur.execute('''
    SELECT COUNT(*) FROM (
        SELECT DISTINCT source_file_acquisition, packet_id 
        FROM spb_processing_v4_flatmap.event WHERE source_data_type_num={source_data_type_num}
    ) AS s
'''.format(source_data_type_num=flight_source_data_type_num))
num_all_packets = cur.fetchone()[0]

cur.execute('''
    SELECT COUNT(*) FROM (
        SELECT DISTINCT source_file_acquisition, packet_id 
        FROM spb_processing_v4_flatmap.event WHERE source_data_type_num={source_data_type_num}
        AND 36 <= gtu_in_packet AND gtu_in_packet <= 60
    ) AS s
'''.format(source_data_type_num=flight_source_data_type_num))
num_gtu_36_60_packets = cur.fetchone()[0]

cur.execute('''
    SELECT COUNT(*) FROM (
        SELECT DISTINCT source_file_acquisition, packet_id 
        FROM spb_processing_v4_flatmap.event WHERE source_data_type_num={source_data_type_num}
        AND 31 <= gtu_in_packet AND gtu_in_packet <= 67
    ) AS s
'''.format(source_data_type_num=flight_source_data_type_num))
num_gtu_31_67_packets = cur.fetchone()[0]

cur.execute('''
    SELECT COUNT(event_id) FROM spb_processing_v4_flatmap.event 
    WHERE source_data_type_num={source_data_type_num}
'''.format(source_data_type_num=flight_source_data_type_num))
num_all_events = cur.fetchone()[0]

cur.execute('''
    SELECT COUNT(event_id) FROM spb_processing_v4_flatmap.event 
    WHERE source_data_type_num={source_data_type_num} 
    AND gtu_in_packet BETWEEN 36 AND 60
'''.format(source_data_type_num=flight_source_data_type_num))
num_gtu_36_60_events = cur.fetchone()[0]

cur.execute('''
    SELECT COUNT(event_id) FROM spb_processing_v4_flatmap.event 
    WHERE source_data_type_num={source_data_type_num} 
    AND gtu_in_packet BETWEEN 31 AND 67
'''.format(source_data_type_num=flight_source_data_type_num))
num_gtu_31_67_events = cur.fetchone()[0]

# %%
print('number of all         packets', num_all_packets)
print('number of gtu [36,60] packets', num_gtu_36_60_packets)
print('number of gtu [31,67] packets', num_gtu_31_67_packets)
print('-'*50)
print('number of all         events ', num_all_events)
print('number of gtu [36,60] events ', num_gtu_36_60_events)
print('number of gtu [31,67] events ', num_gtu_31_67_events)
print('-'*50)
print('sel. fraction of all         events {:.3f}'.format(len(flight_df_nonan) / num_all_events))
print('sel. fraction of gtu [36,60] events {:.3f}'.format(len(flight_df_nonan) / num_gtu_36_60_events))
print('sel. fraction of gtu [31,67] events {:.3f}'.format(len(flight_df_nonan) / num_gtu_31_67_events))
# Out:
# number of all         packets 145648
# number of gtu [36,60] packets 137363
# number of gtu [31,67] packets 139935
# --------------------------------------------------
# number of all         events  243622
# number of gtu [36,60] events  156135
# number of gtu [31,67] events  167354
# --------------------------------------------------
# sel. fraction of all         events 0.449
# sel. fraction of gtu [36,60] events 0.700
# sel. fraction of gtu [31,67] events 0.653

# %% [markdown]
# # Applying models

# %% [markdown]
# This model does not use scaled data

# %%
# standard_scaler_on_train_rfecv_columns_pathname = \
#      os.path.join(model_data_snippets_dir, 'standard_scaler_on_train_rfecv_columns.pkl')
# standard_scaler_on_train_rfecv_columns = joblib.load(standard_scaler_on_train_rfecv_columns_pathname)

# %%
# flight__rfecv_columns_scaled_X = \
#     standard_scaler_on_train_rfecv_columns.transform(
#         flight_df[rfecv_selector_on_extra_trees__column_names].values)
# if np.count_nonzero(flight_df['had_nan_fields']) > 0:
#     flight_nonan__rfecv_columns_scaled_X = \
#         standard_scaler_on_train_rfecv_columns.transform(
#             flight_df_nonan[rfecv_selector_on_extra_trees__column_names].values)
# else:
#     flight_nonan__rfecv_columns_scaled_X = flight__rfecv_columns_scaled_X

# %% [markdown]
# ## Extra trees classifier

# %%
flight_rfecv_columns__X  = flight_df_nonan[rfecv_selector_on_extra_trees__column_names].values

# %%
extra_trees_cls_on_train_rfecv__model_plk_pathname = \
    os.path.join(model_data_snippets_dir, 'extra_trees_cls_on_train_rfecv.pkl')
extra_trees_cls_on_train_rfecv_est = joblib.load(extra_trees_cls_on_train_rfecv__model_plk_pathname)

# %%
cls_column_base = 'extra_trees_cls_on_train_rfecv_est'
cls_column = cls_column_base + '_dropna'
cls_proba_column = 'extra_trees_cls_on_train_rfecv_est_dropna_proba'

# %%
# this might not be correct (but for this particular selection it should be fine becaus flight_df_nonan == flight_df )
flight_df[cls_column_base] = \
    extra_trees_cls_on_train_rfecv_est.predict(flight_rfecv_columns__X)

flight_df[cls_column] = \
    ((flight_df[cls_column_base]==1) & ~flight_df['had_nan_fields']).astype('int8')

# %%
flight_df[cls_proba_column] = np.nan
flight_df.loc[flight_df['event_id'].isin(flight_df_nonan['event_id']), cls_proba_column] = \
    extra_trees_cls_on_train_rfecv_est.predict_proba(flight_rfecv_columns__X)[:,1]

# %% [markdown]
# ### Updating `flight_df_nonan` with classification predictions
# (not in the report)

# %%
flight_df_nonan = flight_df[~flight_df['had_nan_fields']]

# %%
flight_df_nonan[rfecv_selector_on_extra_trees__column_names + ['manual_classification_class_number']].head()
# Out:
#    trg_box_per_gtu_max  trg_box_per_gtu_sum  trg_box_per_gtu_mean  \
# 0                  7.0                  9.0              0.818182
# 1                  7.0                 15.0              1.363640
# 2                  7.0                 22.0              1.000000
# 3                526.0               1012.0             67.466700
# 4                668.0               8379.0            253.909000
#
#    trg_pmt_per_gtu_sum  trg_pmt_per_gtu_mean  trg_ec_per_gtu_sum  \
# 0                  3.0              0.272727                 3.0
# 1                  4.0              0.363636                 3.0
# 2                 10.0              0.454545                10.0
# 3                 68.0              4.533330                20.0
# 4                638.0             19.333300               200.0
#
#    trg_ec_per_gtu_mean  trg_x_y_clusters_sizes_min  \
# 0             0.272727                           1
# 1             0.272727                           7
# 2             0.454545                          16
# 3             1.333330                         592
# 4             6.060610                         940
#
#    trg_x_y_clusters_sizes_max  trg_x_y_clusters_clu_areas_max  \
# 0                           7                               9
# 1                           7                              42
# 2                          16                             126
# 3                         592                            2116
# 4                         940                            2116
#
#                   ...                  \
# 0                 ...
# 1                 ...
# 2                 ...
# 3                 ...
# 4                 ...
#
#    alt1_x_y_hough_peak_thr3_major_line_phi  \
# 0                                 1.448210
# 1                                 1.290240
# 2                                 0.195124
# 3                                 1.580070
# 4                                 0.582123
#
#    alt1_gtu_x_hough_peak_thr1_major_line_rho  \
# 0                                    4.74049
# 1                                    2.31214
# 2                                    2.44340
# 3                                    9.05172
# 4                                   16.28690
#
#    alt1_gtu_x_hough_peak_thr2_major_line_rho  \
# 0                                    4.60184
# 1                                    1.70155
# 2                                    5.69936
# 3                                    8.84120
# 4                                   15.53590
#
#    alt1_gtu_x_hough_peak_thr3_major_line_rho  \
# 0                                    5.41446
# 1                                    2.29509
# 2                                    5.69849
# 3                                    8.84120
# 4                                   13.86160
#
#    alt1_gtu_y_hough_peak_thr1_major_line_rho  \
# 0                                    5.14926
# 1                                    3.20554
# 2                                    1.11428
# 3                                    9.34996
# 4                                   16.24120
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_sizes_max  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    manual_classification_class_number
# 0                                -1.0
# 1                                -1.0
# 2                                -1.0
# 3                                -1.0
# 4                                -1.0
#
# [5 rows x 233 columns]

# %% [markdown]
# ### Statistics of selected events

# %%
np.count_nonzero(flight_df[cls_column])
# Out:
# 9267

# %%
np.count_nonzero(flight_df[cls_column])/len(flight_df)
# Out:
# 0.0847842197235158

# %%
flight_df[[cls_column, cls_proba_column]].describe()
# Out:
#        extra_trees_cls_on_train_rfecv_est_dropna  \
# count                              109301.000000
# mean                                    0.084784
# std                                     0.278562
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        extra_trees_cls_on_train_rfecv_est_dropna_proba
# count                                    109301.000000
# mean                                          0.187138
# std                                           0.190741
# min                                           0.000000
# 25%                                           0.039062
# 50%                                           0.125000
# 75%                                           0.281250
# max                                           1.000000

# %% [markdown]
# #### Events classified "air shower" - number of events by probability

# %%
for proba in np.arange(0.5, 1.0, 0.1):
    print('p > {:.2f}: {}'.format(proba, np.count_nonzero(flight_df[cls_proba_column] > proba)))
# Out:
# p > 0.50: 9267
# p > 0.60: 4910
# p > 0.70: 2277
# p > 0.80: 900
# p > 0.90: 271

# %% [markdown]
# #### Events classified "air shower" - fraction of all events

# %%
np.count_nonzero(flight_df_nonan[cls_column])/num_all_events
# Out:
# 0.038038436594396235

# %% [markdown]
# #### Events classified "air shower" - fraction of all events in gtu [36, 60]

# %%
np.count_nonzero(flight_df_nonan.query('gtu_in_packet >= 36 and gtu_in_packet <= 60')[cls_column])/num_gtu_36_60_events
# Out:
# 0.05845582348608576

# %% [markdown]
# #### Packets classified "air shower" - fraction of all packets

# %%
num_cls_1_packets = \
    len(flight_df_nonan[flight_df_nonan[cls_column] == 1].groupby(
        ['source_file_acquisition', 'packet_id']).count()['event_id'])

# %%
num_cls_1_packets/num_all_packets
# Out:
# 0.06355734373283532

# %% [markdown]
# #### Events classified "air shower" - fraction of all packets triggered in gtu [36, 60]

# %%
num_cls_1_gtu_36_60_packets = \
    len(flight_df_nonan[flight_df_nonan[cls_column] == 1] \
            .query('gtu_in_packet >= 36 and gtu_in_packet <= 60') \
            .groupby(['source_file_acquisition', 'packet_id']) \
            .count()['event_id'])

# %%
num_cls_1_gtu_36_60_packets/num_gtu_36_60_events
# Out:
# 0.05843660934447754

# %% [markdown]
# ### Distribution of classified events by date

# %%
fig, ax = plt.subplots(figsize=(10,4))
flight_df_nonan['gps_datetime_min'].hist(ax=ax, bins=100, color='silver')
flight_df_nonan['gps_datetime_min'][flight_df_nonan[cls_column] == 1].hist(ax=ax, bins=100, color='red')
ax.set_yscale('log')
ax.set_ylabel('Number of events')
ax.set_xlabel('Event time')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
flight_df_nonan['gps_datetime_min'].hist(ax=ax, bins=100, color='silver')
flight_df_nonan['gps_datetime_min'][flight_df_nonan[cls_column] == 1].hist(ax=ax, bins=100, color='red')
# ax.set_yscale('log')
ax.set_ylabel('Number of events')
ax.set_xlabel('Event time')
plt.show()

# %% [markdown]
# ### Trigger rate

# %% [markdown]
# #### All flight HW events

# %%
# hw_trigger_num_per_file = joblib.load('trigger_rate_for_l1trg/hw_trg2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_trigger_num_per_file.pkl')
hw_trigger_rate_per_file = joblib.load('trigger_rate_for_l1trg/hw_trg2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_trigger_rate_per_file.pkl')
hw_file_trigger_datetimes = joblib.load('trigger_rate_for_l1trg/hw_trg2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_trigger_datetimes.pkl')
# hw_file_trigger_p_r = joblib.load('trigger_rate_for_l1trg/hw_trg2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_trigger_p_r.pkl')
# hw_file_trigger_timedelta = joblib.load('trigger_rate_for_l1trg/hw_trg2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_trigger_timedelta.pkl')
# hw_file_indices = joblib.load('trigger_rate_for_l1trg/hw_trg2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_indices.pkl')

# %% [markdown]
# #### All bgf=0.5 events

# %%
# bgf05_trigger_num_per_file_list = joblib.load('trigger_rate_for_l1trg/bgf05_with_flatmap2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_trigger_num_per_file.pkl')
bgf05_trigger_rate_per_file_list = joblib.load('trigger_rate_for_l1trg/bgf05_with_flatmap2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_trigger_rate_per_file.pkl')
bgf05_file_trigger_datetimes_list = joblib.load('trigger_rate_for_l1trg/bgf05_with_flatmap2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_trigger_datetimes.pkl')
# bgf05_file_trigger_p_r_list = joblib.load('trigger_rate_for_l1trg/bgf05_with_flatmap2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_trigger_p_r.pkl')
# bgf05_file_trigger_timedelta_list = joblib.load('trigger_rate_for_l1trg/bgf05_with_flatmap2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_trigger_timedelta.pkl')
# bgf05_file_indices_list = joblib.load('trigger_rate_for_l1trg/bgf05_with_flatmap2feee3b0332fbd7fea6241885d90f2aa_one_trg_per_packet_128_file_indices.pkl')

# %%
fig, ax_scatter, ax_histx, ax_histy = \
    vis_trigger_rate_w_distributions(
        hw_file_trigger_datetimes,
        hw_trigger_rate_per_file, 
        ylim=(10**(-2.5), 10**(2.5)),
        label='Hardware', color='C0', hist_alpha=.5, scatter_alpha=.5,
        show=False
    )
# gray

vis_trigger_rate_w_distributions(
    bgf05_file_trigger_datetimes_list,
    bgf05_trigger_rate_per_file_list,
    ylim=(10**(-2.5), 10**(2.5)), 
    label='Software L1 trigger', color='C1', hist_alpha=.5, scatter_alpha=.35,
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_hw_vs_bgf05.png'),
    ax_scatter=ax_scatter, ax_histx=ax_histx, ax_histy=ax_histy,
    legend=True, legend_kwargs={'loc': 'lower right'},
    show=True
);
# dodgerblue

# %% [markdown]
# #### All classified events

# %%
all_classified_trigger_datetime_list, all_classified_trigger_rate_list = \
    count_trigger_rate_per_file_from_df(flight_df_nonan,  one_trg_per='packet')
# Out:
# 1/987 allpackets-SPBEUSO-ACQUISITION-20170424-150143-001.001--CHECK.root
# 2/987 allpackets-SPBEUSO-ACQUISITION-20170424-150228-001.001--LONG.root
# 3/987 allpackets-SPBEUSO-ACQUISITION-20170424-150228-002.001--LONG.root
# 4/987 allpackets-SPBEUSO-ACQUISITION-20170424-150228-003.001--LONG.root
# 5/987 allpackets-SPBEUSO-ACQUISITION-20170424-150228-004.001--LONG.root
# 6/987 allpackets-SPBEUSO-ACQUISITION-20170424-150228-005.001--LONG.root
# 7/987 allpackets-SPBEUSO-ACQUISITION-20170424-172343-001.001--CHECK.root
# 8/987 allpackets-SPBEUSO-ACQUISITION-20170424-172427-001.001--LONG.root
# 9/987 allpackets-SPBEUSO-ACQUISITION-20170424-172427-002.001--LONG.root
# 10/987 allpackets-SPBEUSO-ACQUISITION-20170424-172427-003.001--LONG.root
# 11/987 allpackets-SPBEUSO-ACQUISITION-20170424-172427-004.001--LONG.root
# 12/987 allpackets-SPBEUSO-ACQUISITION-20170424-172427-005.001--LONG.root
# 13/987 allpackets-SPBEUSO-ACQUISITION-20170425-104043-001.001--CHECK.root
# 14/987 allpackets-SPBEUSO-ACQUISITION-20170425-104127-002.001--LONG.root
# 15/987 allpackets-SPBEUSO-ACQUISITION-20170425-104127-007.001--LONG.root
# 16/987 allpackets-SPBEUSO-ACQUISITION-20170425-104127-011.001--LONG.root
# 17/987 allpackets-SPBEUSO-ACQUISITION-20170425-113210-001.001--CHECK.root
# 18/987 allpackets-SPBEUSO-ACQUISITION-20170425-113254-002.001--LONG.root
# 19/987 allpackets-SPBEUSO-ACQUISITION-20170425-113254-003.001--LONG.root
# 20/987 allpackets-SPBEUSO-ACQUISITION-20170425-113254-004.001--LONG.root
# 21/987 allpackets-SPBEUSO-ACQUISITION-20170425-115113-001.001--CHECK.root
# 22/987 allpackets-SPBEUSO-ACQUISITION-20170425-115157-001.001--LONG.root
# 23/987 allpackets-SPBEUSO-ACQUISITION-20170425-115157-002.001--LONG.root
# 24/987 allpackets-SPBEUSO-ACQUISITION-20170425-115837-001.001--CHECK.root
# 25/987 allpackets-SPBEUSO-ACQUISITION-20170425-115921-004.001--LONG.root
# 26/987 allpackets-SPBEUSO-ACQUISITION-20170425-115921-008.001--LONG.root
# 27/987 allpackets-SPBEUSO-ACQUISITION-20170425-122821-001.001--LONG.root
# 28/987 allpackets-SPBEUSO-ACQUISITION-20170425-122850-001.001--LONG.root
# 29/987 allpackets-SPBEUSO-ACQUISITION-20170425-123129-001.001--LONG.root
# 30/987 allpackets-SPBEUSO-ACQUISITION-20170425-123151-001.001--CHECK.root
# 31/987 allpackets-SPBEUSO-ACQUISITION-20170425-123157-001.001--LONG.root
# 32/987 allpackets-SPBEUSO-ACQUISITION-20170425-135111-001.001--CHECK.root
# 33/987 allpackets-SPBEUSO-ACQUISITION-20170425-142402-001.001--CHECK.root
# 34/987 allpackets-SPBEUSO-ACQUISITION-20170425-172217-001.001--CHECK.root
# 35/987 allpackets-SPBEUSO-ACQUISITION-20170426-125845-001.001--CHECK.root
# 36/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-001.001--LONG.root
# 37/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-002.001--LONG.root
# 38/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-003.001--LONG.root
# 39/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-004.001--LONG.root
# 40/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-005.001--LONG.root
# 41/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-006.001--LONG.root
# 42/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-007.001--LONG.root
# 43/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-008.001--LONG.root
# 44/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-009.001--LONG.root
# 45/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-010.001--LONG.root
# 46/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-011.001--LONG.root
# 47/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-012.001--LONG.root
# 48/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-013.001--LONG.root
# 49/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-014.001--LONG.root
# 50/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-015.001--LONG.root
# 51/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-016.001--LONG.root
# 52/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-017.001--LONG.root
# 53/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-018.001--LONG.root
# 54/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-019.001--LONG.root
# 55/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-020.001--LONG.root
# 56/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-021.001--LONG.root
# 57/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-022.001--LONG.root
# 58/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-023.001--LONG.root
# 59/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-024.001--LONG.root
# 60/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-025.001--LONG.root
# 61/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-026.001--LONG.root
# 62/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-027.001--LONG.root
# 63/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-028.001--LONG.root
# 64/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-029.001--LONG.root
# 65/987 allpackets-SPBEUSO-ACQUISITION-20170426-125930-030.001--LONG.root
# 66/987 allpackets-SPBEUSO-ACQUISITION-20170426-135950-001.001--CHECK.root
# 67/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-001.001--LONG.root
# 68/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-003.001--LONG.root
# 69/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-004.001--LONG.root
# 70/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-009.001--LONG.root
# 71/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-011.001--LONG.root
# 72/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-013.001--LONG.root
# 73/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-018.001--LONG.root
# 74/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-021.001--LONG.root
# 75/987 allpackets-SPBEUSO-ACQUISITION-20170426-140034-024.001--LONG.root
987 allpackets-SPBEUSO-ACQUISITION-20170428-120707-029.001--LONG.root
# 289/987 allpackets-SPBEUSO-ACQUISITION-20170428-120707-030.001--LONG.root
# 290/987 allpackets-SPBEUSO-ACQUISITION-20170428-130727-001.001--CHECK.root
# 291/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-001.001--LONG.root
# 292/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-002.001--LONG.root
# 293/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-003.001--LONG.root
# 294/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-004.001--LONG.root
# 295/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-005.001--LONG.root
# 296/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-006.001--LONG.root
# 297/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-007.001--LONG.root
# 298/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-008.001--LONG.root
# 299/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-009.001--LONG.root
# 300/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-010.001--LONG.root
# 301/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-011.001--LONG.root
# 302/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-012.001--LONG.root
# 303/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-013.001--LONG.root
# 304/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-014.001--LONG.root
# 305/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-015.001--LONG.root
# 306/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-016.001--LONG.root
# 307/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-017.001--LONG.root
# 308/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-018.001--LONG.root
# 309/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-019.001--LONG.root
# 310/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-020.001--LONG.root
# 311/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-021.001--LONG.root
# 312/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-022.001--LONG.root
# 313/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-023.001--LONG.root
# 314/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-024.001--LONG.root
# 315/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-025.001--LONG.root
# 316/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-026.001--LONG.root
# 317/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-027.001--LONG.root
# 318/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-028.001--LONG.root
# 319/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-029.001--LONG.root
# 320/987 allpackets-SPBEUSO-ACQUISITION-20170428-130811-030.001--LONG.root
# 321/987 allpackets-SPBEUSO-ACQUISITION-20170428-140831-001.001--CHECK.root
# 322/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-001.001--LONG.root
# 323/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-002.001--LONG.root
# 324/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-003.001--LONG.root
# 325/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-004.001--LONG.root
# 326/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-005.001--LONG.root
# 327/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-006.001--LONG.root
# 328/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-007.001--LONG.root
# 329/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-008.001--LONG.root
# 330/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-009.001--LONG.root
# 331/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-010.001--LONG.root
# 332/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-011.001--LONG.root
# 333/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-012.001--LONG.root
# 334/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-013.001--LONG.root
# 335/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-014.001--LONG.root
# 336/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-015.001--LONG.root
# 337/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-016.001--LONG.root
# 338/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-017.001--LONG.root
# 339/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-018.001--LONG.root
# 340/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-019.001--LONG.root
# 341/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-020.001--LONG.root
# 342/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-021.001--LONG.root
# 343/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-022.001--LONG.root
# 344/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-023.001--LONG.root
# 345/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-024.001--LONG.root
# 346/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-025.001--LONG.root
# 347/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-026.001--LONG.root
# 348/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-027.001--LONG.root
# 349/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-028.001--LONG.root
# 350/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-029.001--LONG.root
# 351/987 allpackets-SPBEUSO-ACQUISITION-20170428-140915-030.001--LONG.root
# 352/987 allpackets-SPBEUSO-ACQUISITION-20170428-150935-001.001--CHECK.root
# 353/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-001.001--LONG.root
# 354/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-003.001--LONG.root
# 355/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-008.001--LONG.root
# 356/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-009.001--LONG.root
# 357/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-012.001--LONG.root
# 358/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-013.001--LONG.root
# 359/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-014.001--LONG.root
# 360/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-016.001--LONG.root
# 361/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-019.001--LONG.root
# 362/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-022.001--LONG.root
# 363/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-023.001--LONG.root
# 364/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-024.001--LONG.root
# 365/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-026.001--LONG.root
# 366/987 allpackets-SPBEUSO-ACQUISITION-20170428-151019-027.001--LONG.root
# 367/987 allpackets-SPBEUSO-ACQUISITION-20170428-160759-001.001--CHECK.root
# 368/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-001.001--LONG.root
# 369/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-002.001--LONG.root
# 370/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-003.001--LONG.root
# 371/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-004.001--LONG.root
# 372/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-005.001--LONG.root
# 373/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-006.001--LONG.root
# 374/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-007.001--LONG.root
# 375/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-008.001--LONG.root
# 376/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-009.001--LONG.root
# 377/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-010.001--LONG.root
# 378/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-011.001--LONG.root
# 379/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-012.001--LONG.root
# 380/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-013.001--LONG.root
# 381/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-014.001--LONG.root
# 382/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-015.001--LONG.root
# 383/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-016.001--LONG.root
# 384/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-017.001--LONG.root
# 385/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-018.001--LONG.root
# 386/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-019.001--LONG.root
# 387/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-020.001--LONG.root
# 388/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-021.001--LONG.root
# 389/987 allpackets-SPBEUSO-ACQUISITION-20170428-161317-022.001--LONG.root
# 390/987 allpackets-SPBEUSO-ACQUISITION-20170429-055842-001.001--CHECK.root
# 391/987 allpackets-SPBEUSO-ACQUISITION-20170429-055927-001.001--LONG.root
# 392/987 allpackets-SPBEUSO-ACQUISITION-20170429-055927-007.001--LONG.root
# 393/987 allpackets-SPBEUSO-ACQUISITION-20170429-055927-010.001--LONG.root
# 394/987 allpackets-SPBEUSO-ACQUISITION-20170429-055927-014.001--LONG.root
# 395/987 allpackets-SPBEUSO-ACQUISITION-20170429-055927-019.001--LONG.root
# 396/987 allpackets-SPBEUSO-ACQUISITION-20170429-055927-024.001--LONG.root
# 397/987 allpackets-SPBEUSO-ACQUISITION-20170429-065947-001.001--CHECK.root
# 398/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-003.001--LONG.root
# 399/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-004.001--LONG.root
# 400/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-006.001--LONG.root
# 401/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-008.001--LONG.root
# 402/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-009.001--LONG.root
# 403/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-012.001--LONG.root
# 404/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-013.001--LONG.root
# 405/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-014.001--LONG.root
# 406/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-016.001--LONG.root
# 407/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-017.001--LONG.root
# 408/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-019.001--LONG.root
# 409/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-020.001--LONG.root
# 410/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-021.001--LONG.root
# 411/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-025.001--LONG.root
# 412/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-026.001--LONG.root
# 413/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-027.001--LONG.root
# 414/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-028.001--LONG.root
# 415/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-029.001--LONG.root
# 416/987 allpackets-SPBEUSO-ACQUISITION-20170429-070031-030.001--LONG.root
# 417/987 allpackets-SPBEUSO-ACQUISITION-20170429-080051-001.001--CHECK.root
# 418/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-001.001--LONG.root
# 419/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-002.001--LONG.root
# 420/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-003.001--LONG.root
# 421/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-004.001--LONG.root
# 422/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-005.001--LONG.root
# 423/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-006.001--LONG.root
# 424/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-007.001--LONG.root
# 425/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-008.001--LONG.root
# 426/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-009.001--LONG.root
# 427/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-010.001--LONG.root
# 428/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-011.001--LONG.root
# 429/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-012.001--LONG.root
# 430/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-013.001--LONG.root
# 431/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-014.001--LONG.root
# 432/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-015.001--LONG.root
# 433/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-016.001--LONG.root
# 434/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-017.001--LONG.root
# 435/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-018.001--LONG.root
# 436/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-019.001--LONG.root
# 437/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-020.001--LONG.root
# 438/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-021.001--LONG.root
# 439/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-022.001--LONG.root
# 440/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-023.001--LONG.root
# 441/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-024.001--LONG.root
# 442/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-025.001--LONG.root
# 443/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-026.001--LONG.root
# 444/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-027.001--LONG.root
# 445/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-028.001--LONG.root
# 446/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-029.001--LONG.root
# 447/987 allpackets-SPBEUSO-ACQUISITION-20170429-080135-030.001--LONG.root
# 448/987 allpackets-SPBEUSO-ACQUISITION-20170429-090155-001.001--CHECK.root
# 449/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-001.001--LONG-sqz.root
# 450/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-001.001--LONG.root
# 451/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-003.001--LONG.root
# 452/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-005.001--LONG-sqz.root
# 453/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-005.001--LONG.root
# 454/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-007.001--LONG.root
# 455/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-009.001--LONG-sqz.root
# 456/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-014.001--LONG-sqz.root
# 457/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-017.001--LONG-sqz.root
# 458/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-020.001--LONG.root
# 459/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-022.001--LONG.root
# 460/987 allpackets-SPBEUSO-ACQUISITION-20170429-090239-023.001--LONG-sqz.root
# 461/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-001.001--LONG-sqz.root
# 462/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-003.001--LONG.root
# 463/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-004.001--LONG.root
# 464/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-006.001--LONG-sqz.root
# 465/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-009.001--LONG.root
# 466/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-010.001--LONG-sqz.root
# 467/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-010.001--LONG.root
# 468/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-014.001--LONG-sqz.root
# 469/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-015.001--LONG.root
# 470/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-017.001--LONG.root
# 471/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-018.001--LONG-sqz.root
# 472/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-018.001--LONG.root
# 473/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-022.001--LONG-sqz.root
# 474/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-022.001--LONG.root
# 475/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-025.001--LONG-sqz.root
# 476/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-026.001--LONG.root
# 477/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-029.001--LONG-sqz.root
# 478/987 allpackets-SPBEUSO-ACQUISITION-20170429-100343-029.001--LONG.root
# 479/987 allpackets-SPBEUSO-ACQUISITION-20170429-110404-001.001--CHECK.root
# 480/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-001.001--LONG-sqz.root
# 481/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-002.001--LONG-sqz.root
# 482/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-003.001--LONG-sqz.root
# 483/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-003.001--LONG.root
# 484/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-004.001--LONG-sqz.root
# 485/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-004.001--LONG.root
# 486/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-005.001--LONG-sqz.root
# 487/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-005.001--LONG.root
# 488/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-006.001--LONG-sqz.root
# 489/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-007.001--LONG-sqz.root
# 490/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448-008.001--LONG-sqz.root
# 491/987 allpackets-SPBEUSO-ACQUISITION-20170429-110448
987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-014.001--LONG-sqz.root
# 956/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-015.001--LONG-sqz.root
# 957/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-016.001--LONG-sqz.root
# 958/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-017.001--LONG-sqz.root
# 959/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-018.001--LONG-sqz.root
# 960/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-019.001--LONG-sqz.root
# 961/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-020.001--LONG-sqz.root
# 962/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-021.001--LONG-sqz.root
# 963/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-022.001--LONG-sqz.root
# 964/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-023.001--LONG-sqz.root
# 965/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-024.001--LONG-sqz.root
# 966/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-025.001--LONG-sqz.root
# 967/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-026.001--LONG-sqz.root
# 968/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-027.001--LONG-sqz.root
# 969/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-028.001--LONG-sqz.root
# 970/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-029.001--LONG-sqz.root
# 971/987 allpackets-SPBEUSO-ACQUISITION-20170502-134901-030.001--LONG-sqz.root
# 972/987 allpackets-SPBEUSO-ACQUISITION-20170502-144913-001.001--CHECK.root
# 973/987 allpackets-SPBEUSO-ACQUISITION-20170503-085415-001.001--CHECK.root
# 974/987 allpackets-SPBEUSO-ACQUISITION-20170503-085728-001.001--CHECK.root
# 975/987 allpackets-SPBEUSO-ACQUISITION-20170503-090032-001.001--CHECK.root
# 976/987 allpackets-SPBEUSO-ACQUISITION-20170503-111308-001.001--CHECK.root
# 977/987 allpackets-SPBEUSO-ACQUISITION-20170503-122552-001.001--CHECK.root
# 978/987 allpackets-SPBEUSO-ACQUISITION-20170503-135121-001.001--CHECK.root
# 979/987 allpackets-SPBEUSO-ACQUISITION-20170504-113024-001.001--CHECK.root
# 980/987 allpackets-SPBEUSO-ACQUISITION-20170504-123121-001.001--CHECK.root
# 981/987 allpackets-SPBEUSO-ACQUISITION-20170504-133219-001.001--CHECK.root
# 982/987 allpackets-SPBEUSO-ACQUISITION-20170505-100211-001.001--CHECK.root
# 983/987 allpackets-SPBEUSO-ACQUISITION-20170505-100435-001.001--CHECK.root
# 984/987 allpackets-SPBEUSO-ACQUISITION-20170505-110545-001.001--CHECK.root
# 985/987 allpackets-SPBEUSO-ACQUISITION-20170505-120644-001.001--CHECK.root
# 986/987 allpackets-SPBEUSO-ACQUISITION-20170506-102615-001.001--CHECK.root
# 987/987 allpackets-SPBEUSO-ACQUISITION-20170506-112714-001.001--CHECK.root

# %%
vis_trigger_rate_w_distributions(
    all_classified_trigger_datetime_list, 
    all_classified_trigger_rate_list,
    ylim=(10**(-2.5), 10**(2.5)),
    color='C3',
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_classified_all.png')
);
# limegreen

# %%
fig, ax_scatter, ax_histx, ax_histy = \
    vis_trigger_rate_w_distributions(
        bgf05_file_trigger_datetimes_list,
        bgf05_trigger_rate_per_file_list,
        ylim=(10**(-2.5), 10**(2.5)),
        label='Software L1 trigger', color='C2', hist_alpha=.5, scatter_alpha=.5,
        show=False
    )
#dodgerblue

vis_trigger_rate_w_distributions(
    all_classified_trigger_datetime_list, 
    all_classified_trigger_rate_list,
    ylim=(10**(-2.5), 10**(2.5)), 
    label='Preselection before classification', color='C3', hist_alpha=.3, scatter_alpha=.35,
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_bgf05_vs_classified.png'),
    ax_scatter=ax_scatter, ax_histx=ax_histx, ax_histy=ax_histy,
    legend=True, legend_kwargs={'loc': 'lower right'},
    show=True
);

# %% [markdown]
# #### Events classified as "air shower"

# %%
shower_trigger_datetime_list, shower_trigger_rate_list = \
    count_trigger_rate_per_file_from_df(flight_df_nonan[flight_df_nonan[cls_column] == 1],  one_trg_per='packet')
# Out:
# 1/322 allpackets-SPBEUSO-ACQUISITION-20170426-125930-009.001--LONG.root
# 2/322 allpackets-SPBEUSO-ACQUISITION-20170426-125930-012.001--LONG.root
# 3/322 allpackets-SPBEUSO-ACQUISITION-20170426-125930-015.001--LONG.root
# 4/322 allpackets-SPBEUSO-ACQUISITION-20170426-125930-016.001--LONG.root
# 5/322 allpackets-SPBEUSO-ACQUISITION-20170426-125930-024.001--LONG.root
# 6/322 allpackets-SPBEUSO-ACQUISITION-20170426-125930-029.001--LONG.root
# 7/322 allpackets-SPBEUSO-ACQUISITION-20170426-140034-004.001--LONG.root
# 8/322 allpackets-SPBEUSO-ACQUISITION-20170426-140034-013.001--LONG.root
# 9/322 allpackets-SPBEUSO-ACQUISITION-20170426-140034-021.001--LONG.root
# 10/322 allpackets-SPBEUSO-ACQUISITION-20170426-150138-025.001--LONG.root
# 11/322 allpackets-SPBEUSO-ACQUISITION-20170427-082510-001.001--CHECK.root
# 12/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-002.001--LONG-sqz.root
# 13/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-003.001--LONG-sqz.root
# 14/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-004.001--LONG-sqz.root
# 15/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-007.001--LONG-sqz.root
# 16/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-008.001--LONG-sqz.root
# 17/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-008.001--LONG.root
# 18/322 allpackets-SPBEUSO-ACQUISITION-20170427-082554-010.001--LONG.root
# 19/322 allpackets-SPBEUSO-ACQUISITION-20170427-105115-001.001--CHECK.root
# 20/322 allpackets-SPBEUSO-ACQUISITION-20170427-105159-005.001--LONG-sqz.root
# 21/322 allpackets-SPBEUSO-ACQUISITION-20170427-115219-001.001--CHECK.root
# 22/322 allpackets-SPBEUSO-ACQUISITION-20170427-115303-002.001--LONG-sqz-dis.root
# 23/322 allpackets-SPBEUSO-ACQUISITION-20170427-115303-013.001--LONG-sqz-dis.root
# 24/322 allpackets-SPBEUSO-ACQUISITION-20170427-115303-013.001--LONG-sqz.root
# 25/322 allpackets-SPBEUSO-ACQUISITION-20170427-115303-014.001--LONG-sqz-dis.root
# 26/322 allpackets-SPBEUSO-ACQUISITION-20170427-115303-014.001--LONG-sqz.root
# 27/322 allpackets-SPBEUSO-ACQUISITION-20170427-125323-001.001--CHECK.root
# 28/322 allpackets-SPBEUSO-ACQUISITION-20170427-125407-002.001--LONG-sqz-dis.root
# 29/322 allpackets-SPBEUSO-ACQUISITION-20170427-125407-004.001--LONG-sqz-dis.root
322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-001.001--LONG.root
# 157/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-002.001--LONG.root
# 158/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-003.001--LONG.root
# 159/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-004.001--LONG.root
# 160/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-005.001--LONG.root
# 161/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-006.001--LONG.root
# 162/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-007.001--LONG.root
# 163/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-008.001--LONG.root
# 164/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-009.001--LONG.root
# 165/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-010.001--LONG.root
# 166/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-011.001--LONG.root
# 167/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-012.001--LONG.root
# 168/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-013.001--LONG.root
# 169/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-014.001--LONG.root
# 170/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-015.001--LONG.root
# 171/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-016.001--LONG.root
# 172/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-017.001--LONG.root
# 173/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-018.001--LONG.root
# 174/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-019.001--LONG.root
# 175/322 allpackets-SPBEUSO-ACQUISITION-20170428-161317-020.001--LONG.root
# 176/322 allpackets-SPBEUSO-ACQUISITION-20170429-055842-001.001--CHECK.root
# 177/322 allpackets-SPBEUSO-ACQUISITION-20170429-055927-001.001--LONG.root
# 178/322 allpackets-SPBEUSO-ACQUISITION-20170429-055927-007.001--LONG.root
# 179/322 allpackets-SPBEUSO-ACQUISITION-20170429-055927-010.001--LONG.root
# 180/322 allpackets-SPBEUSO-ACQUISITION-20170429-055927-014.001--LONG.root
# 181/322 allpackets-SPBEUSO-ACQUISITION-20170429-055927-019.001--LONG.root
# 182/322 allpackets-SPBEUSO-ACQUISITION-20170429-055927-024.001--LONG.root
# 183/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-003.001--LONG.root
# 184/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-004.001--LONG.root
# 185/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-006.001--LONG.root
# 186/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-008.001--LONG.root
# 187/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-009.001--LONG.root
# 188/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-012.001--LONG.root
# 189/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-013.001--LONG.root
# 190/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-014.001--LONG.root
# 191/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-016.001--LONG.root
# 192/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-017.001--LONG.root
# 193/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-019.001--LONG.root
# 194/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-020.001--LONG.root
# 195/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-021.001--LONG.root
# 196/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-025.001--LONG.root
# 197/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-026.001--LONG.root
# 198/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-027.001--LONG.root
# 199/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-028.001--LONG.root
# 200/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-029.001--LONG.root
# 201/322 allpackets-SPBEUSO-ACQUISITION-20170429-070031-030.001--LONG.root
# 202/322 allpackets-SPBEUSO-ACQUISITION-20170429-080051-001.001--CHECK.root
# 203/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-001.001--LONG.root
# 204/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-002.001--LONG.root
# 205/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-003.001--LONG.root
# 206/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-004.001--LONG.root
# 207/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-005.001--LONG.root
# 208/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-006.001--LONG.root
# 209/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-007.001--LONG.root
# 210/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-008.001--LONG.root
# 211/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-009.001--LONG.root
# 212/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-010.001--LONG.root
# 213/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-011.001--LONG.root
# 214/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-012.001--LONG.root
# 215/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-013.001--LONG.root
# 216/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-014.001--LONG.root
# 217/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-015.001--LONG.root
# 218/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-016.001--LONG.root
# 219/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-017.001--LONG.root
# 220/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-018.001--LONG.root
# 221/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-019.001--LONG.root
# 222/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-020.001--LONG.root
# 223/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-021.001--LONG.root
# 224/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-022.001--LONG.root
# 225/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-023.001--LONG.root
# 226/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-024.001--LONG.root
# 227/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-025.001--LONG.root
# 228/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-026.001--LONG.root
# 229/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-027.001--LONG.root
# 230/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135-028.001--LONG.root
# 231/322 allpackets-SPBEUSO-ACQUISITION-20170429-080135
# 300/322 allpackets-SPBEUSO-ACQUISITION-20170501-123259-001.001--CHECK.root
# 301/322 allpackets-SPBEUSO-ACQUISITION-20170501-133354-001.001--CHECK.root
# 302/322 allpackets-SPBEUSO-ACQUISITION-20170502-094433-001.001--CHECK.root
# 303/322 allpackets-SPBEUSO-ACQUISITION-20170502-094518-004.001--LONG-sqz.root
# 304/322 allpackets-SPBEUSO-ACQUISITION-20170502-094518-013.001--LONG-sqz.root
# 305/322 allpackets-SPBEUSO-ACQUISITION-20170502-104529-001.001--CHECK.root
# 306/322 allpackets-SPBEUSO-ACQUISITION-20170502-114710-004.001--LONG-sqz.root
# 307/322 allpackets-SPBEUSO-ACQUISITION-20170502-114710-005.001--LONG-sqz.root
# 308/322 allpackets-SPBEUSO-ACQUISITION-20170502-114710-030.001--LONG-sqz.root
# 309/322 allpackets-SPBEUSO-ACQUISITION-20170502-124722-001.001--CHECK.root
# 310/322 allpackets-SPBEUSO-ACQUISITION-20170502-134817-001.001--CHECK.root
# 311/322 allpackets-SPBEUSO-ACQUISITION-20170502-134901-018.001--LONG-sqz.root
# 312/322 allpackets-SPBEUSO-ACQUISITION-20170502-144913-001.001--CHECK.root
# 313/322 allpackets-SPBEUSO-ACQUISITION-20170503-111308-001.001--CHECK.root
# 314/322 allpackets-SPBEUSO-ACQUISITION-20170503-122552-001.001--CHECK.root
# 315/322 allpackets-SPBEUSO-ACQUISITION-20170503-135121-001.001--CHECK.root
# 316/322 allpackets-SPBEUSO-ACQUISITION-20170504-113024-001.001--CHECK.root
# 317/322 allpackets-SPBEUSO-ACQUISITION-20170504-133219-001.001--CHECK.root
# 318/322 allpackets-SPBEUSO-ACQUISITION-20170505-100435-001.001--CHECK.root
# 319/322 allpackets-SPBEUSO-ACQUISITION-20170505-110545-001.001--CHECK.root
# 320/322 allpackets-SPBEUSO-ACQUISITION-20170505-120644-001.001--CHECK.root
# 321/322 allpackets-SPBEUSO-ACQUISITION-20170506-102615-001.001--CHECK.root
# 322/322 allpackets-SPBEUSO-ACQUISITION-20170506-112714-001.001--CHECK.root

# %%
vis_trigger_rate_w_distributions(
    shower_trigger_datetime_list, 
    shower_trigger_rate_list,
    ylim=(10**(-2.5), 10**(2.5)),
    color='C8',
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_classified_air_shower.png')
);

# %%
fig, ax_scatter, ax_histx, ax_histy = \
    vis_trigger_rate_w_distributions(
        all_classified_trigger_datetime_list, 
        all_classified_trigger_rate_list,
        ylim=(10**(-2.5), 10**(2.5)),
        label='Preselection before classification', color='C3', hist_alpha=.3, scatter_alpha=.5,
        show=False
    )

vis_trigger_rate_w_distributions(
    shower_trigger_datetime_list, 
    shower_trigger_rate_list,
    ylim=(10**(-2.5), 10**(2.5)), 
    label='Classification', color='C8', hist_alpha=.8, scatter_alpha=.6,
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_classified_vs_selected.png'),
    ax_scatter=ax_scatter, ax_histx=ax_histx, ax_histy=ax_histy,
    legend=True, legend_kwargs={'loc': 'lower right'},
    show=True
);

# %%
fig, ax_scatter, ax_histx, ax_histy = \
    vis_trigger_rate_w_distributions(
        hw_file_trigger_datetimes,
        hw_trigger_rate_per_file, 
        ylim=(10**(-2.5), 10**(2.5)),
        label='Hardware', color='C0', hist_alpha=.5, scatter_alpha=.5,
        show=False
    )

vis_trigger_rate_w_distributions(
    shower_trigger_datetime_list, 
    shower_trigger_rate_list,
    ylim=(10**(-2.5), 10**(2.5)), 
    label='Classification', color='C8', hist_alpha=.8, scatter_alpha=.6,
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_hw_vs_selected.png'),
    ax_scatter=ax_scatter, ax_histx=ax_histx, ax_histy=ax_histy,
    legend=True, legend_kwargs={'loc': 'lower right'},
    show=True
);

# %%
fig, ax_scatter, ax_histx, ax_histy = \
    vis_trigger_rate_w_distributions(
        hw_file_trigger_datetimes,
        hw_trigger_rate_per_file, 
        ylim=(10**(-2.5), 10**(2.5)),
        label='Hardware', color='silver', hist_alpha=1, scatter_alpha=1,
        show=False
    )

vis_trigger_rate_w_distributions(
    shower_trigger_datetime_list, 
    shower_trigger_rate_list,
    ylim=(10**(-2.5), 10**(2.5)), 
    label='Classification', color='black', hist_alpha=.5, scatter_alpha=.6,
    base_figure_pathname=os.path.join(data_snippets_dir, 'trg_rate_1_per_packet_hw_vs_selected_bw.png'),
    ax_scatter=ax_scatter, ax_histx=ax_histx, ax_histy=ax_histy,
    legend=True, legend_kwargs={'loc': 'lower right'},
    show=True
);

# %% [markdown]
# #### Summary - mean trigger rate

# %%
print('Mean trigger rate in hardware data:          ', np.mean(hw_trigger_rate_per_file))
print('Mean trigger rate in feature-extracted data: ', np.mean(bgf05_trigger_rate_per_file_list))
print('Mean trigger rate in classified data:        ', np.mean(all_classified_trigger_rate_list))
print('Mean trigger rate in classifer selected data:', np.mean(shower_trigger_rate_list))
# Out:
# Mean trigger rate in hardware data:           1.448051447935921
# Mean trigger rate in feature-extracted data:  1.3001118568232661
# Mean trigger rate in classified data:         0.9263860716700473
# Mean trigger rate in classifer selected data: 0.26327639751552795

# %% [markdown]
# ### Distribution of classified events

# %%
sns.set(style="whitegrid")

# %%
flight_df_nonan[manual_classification_class_name_column].value_counts()
# Out:
# unclassified              107444
# dot                          365
# top_left_ec                  295
# blob                         270
# bg_increased_suddenly        193
# large_blob                   130
# dot_w_blob_behind            123
# few_dots                      84
# bright_blob                   77
# noise                         65
# short_single_gtu_track        53
# single_gtu_track              51
# persistent_dot                29
# unspecified                   22
# 2pix_line                     22
# noise_unspecified             21
# blob_and_dots                 15
# cartesian_line                15
# sparse_blobs                  12
# noise_with_week_dot           12
# storng_light                   3
# Name: manual_classification_class_name, dtype: int64

# %%
# requires manual_classification_class_name_column

for w_unclassified in [False, True]:
    
    print('{} unclassified'.format('With' if w_unclassified else 'Withount'))
    
    for apply_air_shower_filter in [False, True]:
    
        print('Events classified as positive' if apply_air_shower_filter else 'All flight data in the selection')
    
        subset_df = \
            flight_df_nonan[flight_df_nonan[manual_classification_class_number_column] != EVENT_CLASSES['unclassified']] \
            if not w_unclassified else \
            flight_df_nonan
    
        subset_df = subset_df[subset_df[cls_column] == 1] \
            if apply_air_shower_filter else subset_df
    
        fig, ax = plt.subplots(1, figsize=(8,5))
        sns.countplot(y=manual_classification_class_name_column, 
                      data=subset_df, ax=ax, orient='v',
                      order=subset_df[manual_classification_class_name_column].value_counts().index
                     )
        
        ax.set_ylabel('Manual classification label')
        ax.set_xlabel('Number of manually classifed events')

        flight_data_manual_classification_class_name_dist_fig_pathname = \
            os.path.join(
                data_snippets_dir, 
                'flight_data_manual_classification_class_name_distribution{}{}.svg'.format(
                    '_with_unclassified' if w_unclassified else '',
                    '_positive' if apply_air_shower_filter else ''
                ))

        if w_unclassified:
            ax.set_xscale('log')

        fig.savefig(flight_data_manual_classification_class_name_dist_fig_pathname, dpi=150)
        plt.show()
    
    print('='*50)
# Out:
# Withount unclassified
# All flight data in the selection
# Events classified as positive
# ==================================================
# With unclassified
# All flight data in the selection
# Events classified as positive
# ==================================================

# %%
w_unclassified = False
apply_air_shower_filter = True

subset_df = \
    flight_df_nonan[
        flight_df_nonan[manual_classification_class_number_column] != EVENT_CLASSES['unclassified']
    ] if not w_unclassified else flight_df_nonan

print('All flight data in the selection')
print(subset_df.groupby([manual_classification_class_name_column])['event_id'].count())
print('-'*50)
print('Events classified as positive')
print(subset_df[subset_df[cls_column] == 1].groupby([manual_classification_class_name_column])['event_id'].count())
print('-'*50)
print('Ratios')

flight_data_nonan_class_ratios_df = \
    subset_df.groupby([manual_classification_class_name_column])[cls_column] \
        .value_counts(normalize=True).rename('percentage').mul(100).reset_index().sort_values(cls_column)

flight_data_nonan_class_ratios_df #[flight_data_nonan_class_ratios_df[cls_column] == 1]
# Out:
# All flight data in the selection
# manual_classification_class_name
# 2pix_line                  22
# bg_increased_suddenly     193
# blob                      270
# blob_and_dots              15
# bright_blob                77
# cartesian_line             15
# dot                       365
# dot_w_blob_behind         123
# few_dots                   84
# large_blob                130
# noise                      65
# noise_unspecified          21
# noise_with_week_dot        12
# persistent_dot             29
# short_single_gtu_track     53
# single_gtu_track           51
# sparse_blobs               12
# storng_light                3
# top_left_ec               295
# unspecified                22
# Name: event_id, dtype: int64
# --------------------------------------------------
# Events classified as positive
# manual_classification_class_name
# 2pix_line                  1
# blob                      12
# blob_and_dots              1
# bright_blob                2
# cartesian_line             1
# dot                       18
# dot_w_blob_behind          4
# few_dots                   2
# large_blob                 9
# persistent_dot             6
# short_single_gtu_track     7
# single_gtu_track          26
# sparse_blobs               2
# unspecified                2
# Name: event_id, dtype: int64
# --------------------------------------------------
# Ratios
#    manual_classification_class_name  \
# 0                         2pix_line
# 20                noise_unspecified
# 19                            noise
# 24           short_single_gtu_track
# 17                       large_blob
# 32                      unspecified
# 15                         few_dots
# 13                dot_w_blob_behind
# 21              noise_with_week_dot
# 27                 single_gtu_track
# 11                              dot
# 28                     sparse_blobs
# 7                       bright_blob
# 5                     blob_and_dots
# 30                     storng_light
# 3                              blob
# 2             bg_increased_suddenly
# 31                      top_left_ec
# 9                    cartesian_line
# 22                   persistent_dot
# 26                 single_gtu_track
# 25           short_single_gtu_track
# 29                     sparse_blobs
# 16                         few_dots
# 18                       large_blob
# 14                dot_w_blob_behind
# 12                              dot
# 10                   cartesian_line
# 8                       bright_blob
# 6                     blob_and_dots
# 4                              blob
# 1                         2pix_line
# 23                   persistent_dot
# 33                      unspecified
#
#     extra_trees_cls_on_train_rfecv_est_dropna  percentage
# 0                                           0   95.454545
# 20                                          0  100.000000
# 19                                          0  100.000000
# 24                                          0   86.792453
# 17                                          0   93.076923
# 32                                          0   90.909091
# 15                                          0   97.619048
# 13                                          0   96.747967
# 21                                          0  100.000000
# 27                                          0   49.019608
# 11                                          0   95.068493
# 28                                          0   83.333333
# 7                                           0   97.402597
# 5                                           0   93.333333
# 30                                          0  100.000000
# 3                                           0   95.555556
# 2                                           0  100.000000
# 31                                          0  100.000000
# 9                                           0   93.333333
# 22                                          0   79.310345
# 26                                          1   50.980392
# 25                                          1   13.207547
# 29                                          1   16.666667
# 16                                          1    2.380952
# 18                                          1    6.923077
# 14                                          1    3.252033
# 12                                          1    4.931507
# 10                                          1    6.666667
# 8                                           1    2.597403
# 6                                           1    6.666667
# 4                                           1    4.444444
# 1                                           1    4.545455
# 23                                          1   20.689655
# 33                                          1    9.090909

# %%
# flight_data_nonan_class_ratios_df

for w_unclassified in [False, True]:
    
    print('{} unclassified'.format('With' if w_unclassified else 'Withount'))

    subset_df = \
        flight_df_nonan[
            flight_df_nonan[manual_classification_class_number_column] != EVENT_CLASSES['unclassified']
        ] if not w_unclassified else flight_df_nonan

    flight_data_nonan_class_ratios_df = \
        subset_df.groupby([manual_classification_class_name_column])[cls_column] \
            .value_counts(normalize=True).rename('percentage').mul(100).reset_index().sort_values(cls_column)

    fig, ax = plt.subplots(1, figsize=(8,5))

    subset_df = flight_data_nonan_class_ratios_df[flight_data_nonan_class_ratios_df[cls_column] == 1]
    
    p = sns.barplot(y=manual_classification_class_name_column, 
                    x="percentage", #hue=cls_column, 
                    data=subset_df, 
                    ax=ax, orient='h',
                    order=subset_df[manual_classification_class_name_column].iloc[
                        np.argsort(-subset_df["percentage"])]
                   )

    ax.set_ylabel('Manual classification label')
    ax.set_xlabel('Percentage of all events in a class')

    flight_data_manual_classification_class_name_dist_fig_pathname = \
        os.path.join(
            data_snippets_dir, 
            'flight_data_manual_classification_class_name_normalized_distribution{}.svg'.format(
                '_with_unclassified' if w_unclassified else ''
            ))

#     if w_unclassified:
#         ax.set_xscale('log')

    fig.savefig(flight_data_manual_classification_class_name_dist_fig_pathname, dpi=150)
    plt.show()
# Out:
# Withount unclassified
# With unclassified

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ### Saving flight data into tsv
# (not in the report)

# %%
save_flight_data_dump_file = True
overwrite_flight_data_dump_file = False

# %%
if save_flight_data_dump_file:
    flight_data_tsv_pathname = os.path.join(data_snippets_dir, 'flight_data.tsv.gz')

    if overwrite_flight_data_dump_file or not os.path.exists(flight_data_tsv_pathname):
        print('Saving', flight_data_tsv_pathname)
        flight_df.to_csv(flight_data_tsv_pathname, sep='\t', compression='gzip')
    else:
        print('Already exists', flight_data_tsv_pathname)
# Out:
# Already exists ver4_machine_learning_flight_classification_tsne_cfg3_20190217/flight_data.tsv.gz

# %% [markdown]
# # Visualization of the events

# %% [markdown]
# ## Visualizing the features

# %%
flight_df_nonan[rfecv_selector_on_extra_trees__column_names + ['manual_classification_class_number']].head()
# Out:
#    trg_box_per_gtu_max  trg_box_per_gtu_sum  trg_box_per_gtu_mean  \
# 0                  7.0                  9.0              0.818182
# 1                  7.0                 15.0              1.363640
# 2                  7.0                 22.0              1.000000
# 3                526.0               1012.0             67.466700
# 4                668.0               8379.0            253.909000
#
#    trg_pmt_per_gtu_sum  trg_pmt_per_gtu_mean  trg_ec_per_gtu_sum  \
# 0                  3.0              0.272727                 3.0
# 1                  4.0              0.363636                 3.0
# 2                 10.0              0.454545                10.0
# 3                 68.0              4.533330                20.0
# 4                638.0             19.333300               200.0
#
#    trg_ec_per_gtu_mean  trg_x_y_clusters_sizes_min  \
# 0             0.272727                           1
# 1             0.272727                           7
# 2             0.454545                          16
# 3             1.333330                         592
# 4             6.060610                         940
#
#    trg_x_y_clusters_sizes_max  trg_x_y_clusters_clu_areas_max  \
# 0                           7                               9
# 1                           7                              42
# 2                          16                             126
# 3                         592                            2116
# 4                         940                            2116
#
#                   ...                  \
# 0                 ...
# 1                 ...
# 2                 ...
# 3                 ...
# 4                 ...
#
#    alt1_x_y_hough_peak_thr3_major_line_phi  \
# 0                                 1.448210
# 1                                 1.290240
# 2                                 0.195124
# 3                                 1.580070
# 4                                 0.582123
#
#    alt1_gtu_x_hough_peak_thr1_major_line_rho  \
# 0                                    4.74049
# 1                                    2.31214
# 2                                    2.44340
# 3                                    9.05172
# 4                                   16.28690
#
#    alt1_gtu_x_hough_peak_thr2_major_line_rho  \
# 0                                    4.60184
# 1                                    1.70155
# 2                                    5.69936
# 3                                    8.84120
# 4                                   15.53590
#
#    alt1_gtu_x_hough_peak_thr3_major_line_rho  \
# 0                                    5.41446
# 1                                    2.29509
# 2                                    5.69849
# 3                                    8.84120
# 4                                   13.86160
#
#    alt1_gtu_y_hough_peak_thr1_major_line_rho  \
# 0                                    5.14926
# 1                                    3.20554
# 2                                    1.11428
# 3                                    9.34996
# 4                                   16.24120
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_sizes_max  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    alt1_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_size  \
# 0                                                 27
# 1                                                 35
# 2                                                 46
# 3                                                 10
# 4                                                944
#
#    manual_classification_class_number
# 0                                -1.0
# 1                                -1.0
# 2                                -1.0
# 3                                -1.0
# 4                                -1.0
#
# [5 rows x 233 columns]

# %% [markdown]
# ### Features used by the model

# %%
len(rfecv_selector_on_extra_trees__column_names)
# Out:
# 232

# %%
importances = extra_trees_cls_on_train_rfecv_est.feature_importances_
indices = np.argsort(importances)[::-1]


rfecv_selector_on_extra_trees__column_names_indices_importances__sorted = \
    sorted(
        [
            (rfecv_selector_on_extra_trees__column_names[indices[f]], indices[f], importances[indices[f]]) \
            for f in range(len(rfecv_selector_on_extra_trees__column_names)) 
        ], 
        key=lambda e: e[2],
        reverse=True
    )

for column_name, column_indice, column_importance in \
        rfecv_selector_on_extra_trees__column_names_indices_importances__sorted:
    print('{:<70}{:.4f}'.format(column_name,column_importance))


rfecv_selector_on_extra_trees__column_names__sorted = \
    [e[0] for e in rfecv_selector_on_extra_trees__column_names_indices_importances__sorted]

rfecv_selector_on_extra_trees__column_indices__sorted = \
    [e[1] for e in rfecv_selector_on_extra_trees__column_names_indices_importances__sorted]
# Out:
# proc2_x_y_hough_peak_thr1_line_clusters_count                         0.0223
# trg_x_y_hough_peak_thr1_line_clusters_max_size_clu_width              0.0217
# trg_x_y_hough_peak_thr1_line_clusters_clu_widths_max                  0.0212
# trg_x_y_hough_peak_thr1_line_clusters_max_area_clu_width              0.0201
# proc2_x_y_hough_peak_thr1_line_clusters_clu_widths_max                0.0170
# proc3_x_y_hough_peak_thr1_line_clusters_max_sum_clu_width             0.0168
# proc3_x_y_hough_peak_thr2_line_clusters_count                         0.0167
# proc1_x_y_hough_peak_thr1_line_clusters_max_size_clu_width            0.0167
# alt1_x_y_hough_peak_thr1_line_clusters_max_area_clu_width             0.0156
# trg_x_y_hough_peak_thr1_line_clusters_max_peak_clu_width              0.0150
# proc3_x_y_hough_peak_thr1_line_clusters_max_area_clu_width            0.0130
# alt1_x_y_hough_peak_thr1_line_clusters_clu_widths_max                 0.0121
# trg_x_y_hough_peak_thr1_line_clusters_max_sum_clu_width               0.0118
# proc2_x_y_hough_peak_thr1_line_clusters_max_area_clu_width            0.0114
# proc1_x_y_hough_peak_thr1_line_clusters_max_size_clu_height           0.0113
# proc3_x_y_hough_peak_thr1_line_clusters_max_size_clu_width            0.0108
# orig_x_y_count_nonzero                                                0.0105
# alt1_x_y_hough_peak_thr1_line_clusters_count                          0.0105
# trg_x_y_clusters_max_size_clu_height                                  0.0101
# proc2_x_y_hough_peak_thr1_line_clusters_max_size_clu_width            0.0101
# bg_x_y_count_nonzero                                                  0.0101
# alt1_x_y_hough_peak_thr1_line_clusters_max_peak_clu_width             0.0099
# proc3_x_y_hough_peak_thr1_line_clusters_count                         0.0097
# proc3_x_y_hough_peak_thr3_line_clusters_count                         0.0089
# proc1_x_y_hough_peak_thr1_line_clusters_clu_widths_max                0.0088
# alt1_x_y_hough_peak_thr1_line_clusters_max_sum_clu_width              0.0088
# proc3_x_y_clusters_max_peak_clu_height                                0.0084
# proc2_x_y_hough_peak_thr3_line_clusters_count                         0.0083
# alt1_x_y_hough_peak_thr1_line_clusters_max_size_clu_width             0.0081
# proc2_x_y_hough_peak_thr2_line_clusters_count                         0.0081
# proc3_x_y_hough_peak_thr1_line_clusters_clu_widths_max                0.0080
# trg_x_y_clusters_max_peak_clu_height                                  0.0080
# proc1_x_y_hough_peak_thr1_line_clusters_count                         0.0080
# proc2_x_y_hough_peak_thr1_line_clusters_max_peak_clu_width            0.0079
# proc3_gtu_y_hough_peak_thr1_line_clusters_count                       0.0076
# proc3_x_y_hough_peak_thr1_line_clusters_max_peak_clu_width            0.0076
# proc2_x_y_hough_peak_thr1_line_clusters_max_sum_clu_width             0.0074
# alt1_x_y_hough_peak_thr1_line_clusters_max_peak_clu_size              0.0073
# trg_gtu_x_clusters_max_size_clu_height                                0.0071
# proc2_x_y_hough_peak_thr1_line_clusters_clu_heights_max               0.0071
# trg_gtu_y_hough_peak_thr1_line_clusters_clu_widths_max                0.0068
# trg_gtu_y_clusters_max_peak_clu_height                                0.0065
# alt1_x_y_hough_peak_thr2_line_clusters_clu_widths_max                 0.0065
# proc1_x_y_hough_peak_thr2_line_clusters_clu_widths_max                0.0062
# trg_gtu_y_hough_peak_thr1_line_clusters_max_size_clu_width            0.0062
# trg_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_width             0.0061
# trg_gtu_x_hough_peak_thr1_line_clusters_max_size_clu_width            0.0061
# trg_gtu_y_clusters_max_size_clu_height                                0.0058
# trg_x_y_hough_peak_thr2_line_clusters_max_size_clu_width              0.0057
# proc1_x_y_hough_peak_thr1_line_clusters_max_sum_clu_width             0.0053
# trg_x_y_clusters_max_size_clu_width                                   0.0052
# proc1_x_y_hough_peak_thr1_line_clusters_max_area_clu_height           0.0051
# proc1_x_y_hough_peak_thr1_line_clusters_max_peak_clu_size             0.0051
# proc1_x_y_hough_peak_thr1_line_clusters_max_area_clu_width            0.0051
# trg_x_y_clusters_max_peak_clu_width                                   0.0050
# trg_x_y_clusters_sizes_max                                            0.0048
# trg_x_y_hough_peak_thr1_line_clusters_clu_areas_max                   0.0047
# proc1_x_y_hough_peak_thr1_line_clusters_max_sum_clu_height            0.0046
# trg_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_width            0.0046
# proc2_gtu_x_clusters_sizes_max                                        0.0046
# trg_x_y_hough_peak_thr2_line_clusters_clu_widths_max                  0.0044
# trg_gtu_x_hough_peak_thr1_line_clusters_max_peak_clu_width            0.0044
# proc1_x_y_hough_peak_thr1_line_clusters_max_peak_clu_width            0.0042
# proc2_x_y_clusters_clu_areas_max                                      0.0042
# bg_count_nonzero                                                      0.0042
# proc2_x_y_hough_peak_thr1_line_clusters_max_sum_clu_height            0.0041
# proc3_gtu_y_clusters_max_peak_clu_size                                0.0041
# proc2_x_y_hough_peak_thr1_line_clusters_sizes_max                     0.0041
# trg_x_y_clusters_max_peak_clu_size                                    0.0041
# proc1_x_y_hough_peak_thr2_line_clusters_max_sum_clu_width             0.0041
# trg_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_width            0.0040
# trg_gtu_x_hough_peak_thr1_line_clusters_clu_widths_max                0.0040
# trg_x_y_hough_peak_thr2_line_clusters_max_area_clu_width              0.0039
# proc3_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_width          0.0039
# proc1_x_y_hough_peak_thr3_line_clusters_count                         0.0038
# alt1_x_y_hough_peak_thr1_line_clusters_max_sum_clu_size               0.0037
# alt1_x_y_hough_peak_thr2_line_clusters_max_area_clu_width             0.0037
# trg_gtu_x_hough_peak_thr1_line_clusters_max_area_clu_width            0.0037
# proc1_x_y_hough_peak_thr2_line_clusters_count                         0.0037
# alt1_gtu_y_hough_peak_thr1_major_line_rho                             0.0036
# alt1_x_y_hough_peak_thr1_line_clusters_sizes_max                      0.0036
# proc1_x_y_clusters_sizes_min                                          0.0036
# trg_x_y_hough_peak_thr1_line_clusters_max_peak_clu_height             0.0036
# trg_gtu_x_hough_peak_thr1_line_clusters_max_sum_clu_width             0.0035
# trg_x_y_hough_peak_thr2_line_clusters_max_sum_clu_width               0.0035
# trg_gtu_x_clusters_max_peak_clu_height                                0.0035
# proc3_x_y_hough_peak_thr1_line_clusters_clu_heights_max               0.0034
# alt1_x_y_hough_peak_thr1_line_clusters_max_peak_clu_height            0.0034
# alt1_gtu_x_hough_peak_thr1_major_line_rho                             0.0034
# proc2_x_y_hough_peak_thr1_line_clusters_max_sum_clu_size              0.0033
# proc2_gtu_y_clusters_sizes_max                                        0.0032
# trg_box_per_gtu_mean                                                  0.0032
# trg_x_y_hough_peak_thr1_line_clusters_max_area_clu_height             0.0032
# proc2_x_y_hough_peak_thr1_major_line_phi                              0.0032
# proc2_x_y_hough_peak_thr1_line_clusters_max_area_clu_size             0.0032
# trg_gtu_x_clusters_sizes_max                                          0.0032
# proc3_x_y_clusters_max_peak_clu_width                                 0.0031
# alt1_x_y_hough_peak_thr1_line_clusters_max_area_clu_height            0.0031
# proc3_x_y_clusters_max_size_clu_height                                0.0031
# trg_x_y_clusters_clu_areas_max                                        0.0031
# alt1_x_y_hough_peak_thr1_line_clusters_max_area_clu_size              0.0031
# proc3_gtu_x_clusters_max_peak_clu_size                                0.0031
# proc3_x_y_clusters_max_peak_clu_size                                  0.0030
# proc3_gtu_y_hough_peak_thr1_line_clusters_max_size_clu_width          0.0030
# proc2_x_y_hough_peak_thr1_line_clusters_clu_areas_max                 0.0030
# proc3_gtu_x_clusters_sizes_max                                        0.0030
# proc2_gtu_x_hough_peak_thr1_major_line_rho                            0.0030
# proc3_gtu_y_hough_peak_thr1_line_clusters_clu_widths_max              0.0030
# proc3_x_y_hough_peak_thr1_line_clusters_max_sum_clu_size              0.0029
# trg_x_y_hough_peak_thr3_major_line_rho                                0.0029
# trg_count_nonzero                                                     0.0029
# trg_x_y_clusters_sizes_min                                            0.0029
# proc3_gtu_y_clusters_sizes_max                                        0.0028
# proc3_gtu_y_hough_peak_thr2_line_clusters_count                       0.0028
# proc2_x_y_hough_peak_thr3_major_line_phi                              0.0028
# proc1_x_y_hough_peak_thr2_major_line_phi                              0.0028
# trg_box_per_gtu_max                                                   0.0028
# proc1_x_y_hough_peak_thr1_line_clusters_sizes_max                     0.0028
# proc3_x_y_clusters_sizes_max                                          0.0027
# trg_ec_per_gtu_mean                                                   0.0027
# alt1_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_size            0.0027
# alt1_x_y_hough_peak_thr2_line_clusters_count                          0.0027
# proc2_x_y_hough_peak_thr2_line_clusters_clu_heights_max               0.0027
# proc2_x_y_hough_peak_thr1_major_line_rho                              0.0027
# alt1_x_y_hough_peak_thr1_line_clusters_max_size_clu_height            0.0027
# trg_pmt_per_gtu_mean                                                  0.0026
# alt1_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_size            0.0026
# proc2_gtu_y_hough_peak_thr1_line_clusters_max_peak_clu_size           0.0026
# trg_box_per_gtu_sum                                                   0.0026
# trg_gtu_x_clusters_max_peak_clu_size                                  0.0026
# trg_x_y_hough_peak_thr1_line_clusters_max_peak_clu_size               0.0026
# proc3_gtu_x_hough_peak_thr1_line_clusters_count                       0.0025
# proc1_x_y_hough_peak_thr1_line_clusters_max_sum_clu_size              0.0025
# alt1_x_y_hough_peak_thr2_major_line_phi                               0.0025
# proc2_gtu_x_clusters_sizes_min                                        0.0025
# alt1_gtu_x_hough_peak_thr3_major_line_rho                             0.0025
# proc2_x_y_clusters_max_peak_clu_height                                0.0025
# alt1_x_y_hough_peak_thr1_major_line_phi                               0.0025
# proc2_x_y_clusters_sizes_max                                          0.0025
# proc3_x_y_hough_peak_thr2_line_clusters_clu_heights_max               0.0025
# trg_gtu_x_clusters_sizes_min                                          0.0024
# proc2_gtu_x_clusters_max_peak_clu_size                                0.0024
# trg_gtu_x_hough_peak_thr1_line_clusters_max_size_clu_height           0.0024
# proc3_gtu_x_hough_peak_thr2_line_clusters_count                       0.0024
# bg_x_y_sum                                                            0.0024
# proc2_gtu_y_hough_peak_thr1_line_clusters_sizes_max                   0.0024
# alt1_gtu_x_hough_peak_thr2_major_line_rho                             0.0024
# proc1_x_y_clusters_sizes_max                                          0.0024
# trg_x_y_hough_peak_thr1_line_clusters_max_area_clu_size               0.0023
# proc2_x_y_hough_peak_thr2_major_line_phi                              0.0023
# proc2_x_y_hough_peak_thr2_major_line_rho                              0.0023
# bg_size                                                               0.0023
# trg_x_y_hough_peak_thr1_major_line_rho                                0.0023
# proc2_gtu_x_hough_peak_thr2_major_line_rho                            0.0023
# proc3_x_y_hough_peak_thr1_line_clusters_sizes_max                     0.0023
# proc2_gtu_y_hough_peak_thr1_line_clusters_clu_widths_max              0.0023
# trg_x_y_hough_peak_thr1_line_clusters_max_sum_clu_height              0.0023
# proc2_gtu_x_hough_peak_thr3_major_line_rho                            0.0023
# proc2_x_y_hough_peak_thr3_line_clusters_clu_heights_max               0.0023
# trg_gtu_y_clusters_max_peak_clu_size                                  0.0023
# alt1_x_y_hough_peak_thr1_line_clusters_max_sum_clu_height             0.0022
# proc1_x_y_hough_peak_thr1_line_clusters_max_area_clu_size             0.0022
# trg_gtu_y_clusters_sizes_min                                          0.0022
# proc2_x_y_clusters_max_peak_clu_size                                  0.0022
# trg_gtu_y_clusters_sizes_max                                          0.0022
# proc2_x_y_hough_peak_thr1_line_clusters_max_peak_clu_size             0.0022
# proc2_gtu_y_clusters_max_peak_clu_size                                0.0021
# proc1_x_y_hough_peak_thr2_line_clusters_max_size_clu_width            0.0021
# proc3_x_y_clusters_clu_areas_max                                      0.0021
# proc3_x_y_hough_peak_thr1_line_clusters_max_area_clu_size             0.0021
# proc2_x_y_hough_peak_thr1_line_clusters_max_area_clu_height           0.0021
# bg_x_y_mean                                                           0.0021
# proc1_x_y_hough_peak_thr2_major_line_rho                              0.0020
# proc1_gtu_y_clusters_sizes_max                                        0.0020
# proc1_gtu_y_clusters_sizes_min                                        0.0020
# proc1_x_y_hough_peak_thr1_major_line_phi                              0.0020
# proc1_gtu_x_hough_peak_thr2_major_line_rho                            0.0020
# alt1_gtu_y_hough_peak_thr1_line_clusters_sizes_max                    0.0020
# trg_x_y_hough_peak_thr2_line_clusters_max_peak_clu_width              0.0020
# trg_gtu_x_hough_peak_thr2_major_line_rho                              0.0020
# trg_x_y_hough_peak_thr2_major_line_rho                                0.0020
# proc1_x_y_clusters_max_peak_clu_size                                  0.0019
# proc2_x_y_clusters_sizes_min                                          0.0019
# alt1_gtu_x_clusters_sizes_max                                         0.0019
# proc2_gtu_y_hough_peak_thr1_line_clusters_max_size_clu_width          0.0019
# trg_gtu_x_hough_peak_thr1_line_clusters_max_sum_clu_height            0.0019
# proc1_x_y_hough_peak_thr3_major_line_phi                              0.0019
# alt1_x_y_hough_peak_thr2_line_clusters_max_size_clu_width             0.0019
# trg_x_y_hough_peak_thr1_line_clusters_max_sum_clu_size                0.0019
# trg_max                                                               0.0019
# alt1_gtu_x_clusters_max_peak_clu_size                                 0.0019
# trg_pmt_per_gtu_sum                                                   0.0018
# proc2_x_y_hough_peak_thr3_major_line_rho                              0.0018
# proc3_x_y_hough_peak_thr3_line_clusters_clu_heights_max               0.0018
# proc2_x_y_clusters_count                                              0.0018
# proc2_x_y_hough_peak_thr3_major_line_coord_0_x                        0.0018
# trg_gtu_x_hough_peak_thr1_major_line_rho                              0.0018
# proc1_gtu_x_hough_peak_thr1_major_line_rho                            0.0018
# proc2_x_y_hough_peak_thr3_major_line_coord_1_x                        0.0018
# proc2_gtu_y_hough_peak_thr1_line_clusters_max_area_clu_size           0.0018
# proc2_gtu_y_clusters_sizes_min                                        0.0018
# trg_gtu_x_hough_peak_thr3_major_line_rho                              0.0018
# proc1_x_y_hough_peak_thr1_line_clusters_max_peak_clu_height           0.0018
# proc3_gtu_y_clusters_max_peak_clu_width                               0.0017
# trg_x_y_hough_peak_thr1_line_clusters_max_size_clu_height             0.0017
# proc1_gtu_y_clusters_max_peak_clu_size                                0.0017
# proc1_x_y_hough_peak_thr3_major_line_rho                              0.0017
# trg_ec_per_gtu_sum                                                    0.0016
# proc3_x_y_hough_peak_thr1_major_line_phi                              0.0016
# bg_sum                                                                0.0016
# proc2_x_y_clusters_max_peak_clu_width                                 0.0016
# alt1_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_size             0.0016
# proc3_x_y_hough_peak_thr1_line_clusters_max_peak_clu_size             0.0016
# proc1_gtu_x_clusters_max_peak_clu_size                                0.0016
# proc2_gtu_y_hough_peak_thr1_line_clusters_max_sum_clu_size            0.0016
# trg_mean                                                              0.0015
# proc3_x_y_hough_peak_thr2_major_line_phi                              0.0015
# trg_gtu_x_hough_peak_thr1_line_clusters_max_area_clu_height           0.0015
# orig_x_y_max                                                          0.0015
# trg_gtu_x_hough_peak_thr1_line_clusters_clu_areas_max                 0.0015
# bg_mean                                                               0.0015
# orig_mean                                                             0.0015
# proc2_x_y_hough_peak_thr3_major_line_coord_0_y                        0.0015
# orig_mean_gz                                                          0.0014
# proc1_gtu_x_hough_peak_thr3_major_line_rho                            0.0014
# trg_gtu_x_hough_peak_thr1_line_clusters_max_peak_clu_height           0.0014
# proc1_gtu_x_clusters_sizes_min                                        0.0014
# trg_x_y_hough_peak_thr1_line_clusters_clu_heights_max                 0.0014
# alt1_x_y_hough_peak_thr3_major_line_phi                               0.0014
# proc3_x_y_hough_peak_thr3_major_line_coord_1_x                        0.0013
# trg_x_y_hough_peak_thr2_line_clusters_max_peak_clu_height             0.0012
# proc3_x_y_hough_peak_thr1_line_clusters_max_area_clu_height           0.0012

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
#event_v3_storage_provider_flight.connection.reset()

# %%
# flight_nonan_classified_shower_pathname = os.path.join(data_snippets_dir, 'flight_nonan_classified shower.tsv')

# %%
# flight_df_nonan[flight_df_nonan['extra_trees_cls_on_train_kbest400_128_est_dropna']==1].to_csv(flight_nonan_classified_shower_pathname, sep='\t')

# %%
# TODO select clusters with positive classification (sort by the number of classifications) show distribution of event types

# %%
# flight_df_nonan_subset[['dbscan_tsne_y','manual_classification_class_number'].hist('dbscan_tsne_y', figsize=(24,4), bins=2*len(dbscan_on_tsne_classes)+1)

# plt.show()

# %%
# THIS IS NOT WHAT IS DESIRED - values should be split into features ?
# flight_nonan__cls_tsneclu_corr_df = \
#     flight_df_nonan[['dbscan_tsne_y', 'manual_classification_class_number']].corr()
# f, ax = plt.subplots(figsize=(28,22))
# plt.close('all')
# sns.heatmap(flight_nonan__cls_tsneclu_corr_df, cmap='inferno', annot=True)
# plt.show()

# %%
#     f, ax = plt.subplots()
#     f.set_size_inches(8,4)
#     flight_df_nonan_subset[['dbscan_tsne_y', 'manual_classification_class_number']].plot.bar(by='dbscan_tsne_y', ax=ax)

# %%
# flight_nonan__tsne__gmm_y_pred = gmm.predict(flight_df_nonan[['tsne_X_0','tsne_X_1']].values)

# %%
# flight_data__k50best_var_th_scaled_X = \
#     k50best_f_classif_selector_on_var_th_sc_train.transform(
#         var_th_selector_on_scaled_train.transform(
#             standard_scaler_on_train.transform(
#                 unl_flight_df[analyzed_common_df_columns].dropna().values)
#         )
#     )

# extra_trees_classifier_on_train_kbest50__X_flight = flight_data__k50best_var_th_scaled_X
# extra_trees_classifier_on_train_kbest50__y_flight_pred = \
#     extra_trees_classifier_on_train_kbest50.predict(extra_trees_classifier_on_train_kbest50__X_flight)
