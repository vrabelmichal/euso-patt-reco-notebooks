# %%
import sys
import os
import subprocess

app_base_dir = '/home/eusobg/EUSO-SPB/euso-spb-patt-reco-v1'
if app_base_dir not in sys.path:
    sys.path.append(app_base_dir)

import collections
import numpy as np
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as psql
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150
import matplotlib.pyplot as plt
from tqdm import tqdm
import glob
#import ROOT

# %%
import tool.npy_frames_visualization as npy_vis

# %%
con = pg.connect("dbname=eusospb_data user=eusospb password=1e20eVjemeuso host=localhost")
cur = con.cursor()

# %%
simu_events = psql.read_sql(
    "SELECT * FROM simu_event JOIN simu_event_spb_proc USING (simu_event_id);",
    con)

# %%
simu_events
# Out:
#        simu_event_id                                  simu2npy_pathname  \
# 0                  1  /media/node15_data2/SPBDATA_processed/spb_simu...
# 1                  1  /media/node15_data2/SPBDATA_processed/spb_simu...
# 2                  1  /media/node15_data2/SPBDATA_processed/spb_simu...
# 3                  1  /media/node15_data2/SPBDATA_processed/spb_simu...
# 4                  5  /media/node15_data2/SPBDATA_processed/spb_simu...
# 5                  5  /media/node15_data2/SPBDATA_processed/spb_simu...
# 6                  5  /media/node15_data2/SPBDATA_processed/spb_simu...
# 7                  5  /media/node15_data2/SPBDATA_processed/spb_simu...
# 8                  9  /media/node15_data2/SPBDATA_processed/spb_simu...
# 9                  9  /media/node15_data2/SPBDATA_processed/spb_simu...
# 10                 9  /media/node15_data2/SPBDATA_processed/spb_simu...
# 11                 9  /media/node15_data2/SPBDATA_processed/spb_simu...
# 12                 9  /media/node15_data2/SPBDATA_processed/spb_simu...
# 13                14  /media/node15_data2/SPBDATA_processed/spb_simu...
# 14                14  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15                14  /media/node15_data2/SPBDATA_processed/spb_simu...
# 16                14  /media/node15_data2/SPBDATA_processed/spb_simu...
# 17                18  /media/node15_data2/SPBDATA_processed/spb_simu...
# 18                19  /media/node15_data2/SPBDATA_processed/spb_simu...
# 19                19  /media/node15_data2/SPBDATA_processed/spb_simu...
# 20                19  /media/node15_data2/SPBDATA_processed/spb_simu...
# 21                19  /media/node15_data2/SPBDATA_processed/spb_simu...
# 22                23  /media/node15_data2/SPBDATA_processed/spb_simu...
# 23                23  /media/node15_data2/SPBDATA_processed/spb_simu...
# 24                23  /media/node15_data2/SPBDATA_processed/spb_simu...
# 25                23  /media/node15_data2/SPBDATA_processed/spb_simu...
# 26                27  /media/node15_data2/SPBDATA_processed/spb_simu...
# 27                28  /media/node15_data2/SPBDATA_processed/spb_simu...
# 28                28  /media/node15_data2/SPBDATA_processed/spb_simu...
# 29                28  /media/node15_data2/SPBDATA_processed/spb_simu...
# ...              ...                                                ...
# 15309          15309  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15310          15309  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15311          15309  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15312          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15313          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15314          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15315          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15316          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15317          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15318          15313  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15319          15320  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15320          15321  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15321          15321  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15322          15321  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15323          15321  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15324          15325  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15325          15325  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15326          15325  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15327          15325  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15328          15329  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15329          15329  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15330          15329  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15331          15329  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15332          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15333          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15334          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15335          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15336          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15337          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
# 15338          15333  /media/node15_data2/SPBDATA_processed/spb_simu...
#
#                                         npyconv_pathname  num_frames  \
# 0      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 1      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 2      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 3      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 4      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          15
# 5      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          15
# 6      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          15
# 7      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          15
# 8      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          43
# 9      /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          43
# 10     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          43
# 11     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          43
# 12     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          43
# 13     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          18
# 14     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          18
# 15     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          18
# 16     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          18
# 17     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          22
# 18     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           6
# 19     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           6
# 20     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           6
# 21     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           6
# 22     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 23     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 24     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 25     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 26     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          26
# 27     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           9
# 28     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           9
# 29     /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...           9
# ...                                                  ...         ...
# 15309  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          14
# 15310  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          14
# 15311  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          14
# 15312  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15313  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15314  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15315  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15316  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15317  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15318  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15319  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          24
# 15320  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15321  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15322  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15323  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15324  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          13
# 15325  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          13
# 15326  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          13
# 15327  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          13
# 15328  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 15329  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 15330  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 15331  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          16
# 15332  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15333  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15334  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15335  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15336  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15337  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
# 15338  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...          17
#
#        eheader_num  eheader_run eheader_runname  eheader_random_seed  \
# 0                2         1234            Simu            230720146
# 1                2         1234            Simu            230720146
# 2                2         1234            Simu            230720146
# 3                2         1234            Simu            230720146
# 4               22         1234            Simu             71533709
# 5               22         1234            Simu             71533709
# 6               22         1234            Simu             71533709
# 7               22         1234            Simu             71533709
# 8               33         1234            Simu           2714504765
# 9               33         1234            Simu           2714504765
# 10              33         1234            Simu           2714504765
# 11              33         1234            Simu           2714504765
# 12              33         1234            Simu           2714504765
# 13               1         1234            Simu            385548728
# 14               1         1234            Simu            385548728
# 15               1         1234            Simu            385548728
# 16               1         1234            Simu            385548728
# 17               7         1234            Simu           3052111864
# 18              34         1234            Simu           4162542688
# 19              34         1234            Simu           4162542688
# 20              34         1234            Simu           4162542688
# 21              34         1234            Simu           4162542688
# 22              48         1234            Simu           3644319279
# 23              48         1234            Simu           3644319279
# 24              48         1234            Simu           3644319279
# 25              48         1234            Simu           3644319279
# 26              69         1234            Simu            153040485
# 27              16         1234            Simu           3637009002
# 28              16         1234            Simu           3637009002
# 29              16         1234            Simu           3637009002
# ...            ...          ...             ...                  ...
# 15309           63         1234            Simu            562547191
# 15310           63         1234            Simu            562547191
# 15311           63         1234            Simu            562547191
# 15312           77         1234            Simu            865089125
# 15313           77         1234            Simu            865089125
# 15314           77         1234            Simu            865089125
# 15315           77         1234            Simu            865089125
# 15316           77         1234            Simu            865089125
# 15317           77         1234            Simu            865089125
# 15318           77         1234            Simu            865089125
# 15319           25         1234            Simu           3117391763
# 15320           51         1234            Simu           1084347995
# 15321           51         1234            Simu           1084347995
# 15322           51         1234            Simu           1084347995
# 15323           51         1234            Simu           1084347995
# 15324           76         1234            Simu           2664454270
# 15325           76         1234            Simu           2664454270
# 15326           76         1234            Simu           2664454270
# 15327           76         1234            Simu           2664454270
# 15328           82         1234            Simu            255501834
# 15329           82         1234            Simu            255501834
# 15330           82         1234            Simu            255501834
# 15331           82         1234            Simu            255501834
# 15332           94         1234            Simu           2706440357
# 15333           94         1234            Simu           2706440357
# 15334           94         1234            Simu           2706440357
# 15335           94         1234            Simu           2706440357
# 15336           94         1234            Simu           2706440357
# 15337           94         1234            Simu           2706440357
# 15338           94         1234            Simu           2706440357
#
#        eheader_status  edetector_numphotons    ...     \
# 0                   0                 32011    ...
# 1                   0                 32011    ...
# 2                   0                 32011    ...
# 3                   0                 32011    ...
# 4                   0                 21607    ...
# 5                   0                 21607    ...
# 6                   0                 21607    ...
# 7                   0                 21607    ...
# 8                   0                202978    ...
# 9                   0                202978    ...
# 10                  0                202978    ...
# 11                  0                202978    ...
# 12                  0                202978    ...
# 13                  0                 45287    ...
# 14                  0                 45287    ...
# 15                  0                 45287    ...
# 16                  0                 45287    ...
# 17                  0                140413    ...
# 18                  0                 20487    ...
# 19                  0                 20487    ...
# 20                  0                 20487    ...
# 21                  0                 20487    ...
# 22                  0                 24547    ...
# 23                  0                 24547    ...
# 24                  0                 24547    ...
# 25                  0                 24547    ...
# 26                  0                 48615    ...
# 27                  0                 22696    ...
# 28                  0                 22696    ...
# 29                  0                 22696    ...
# ...               ...                   ...    ...
# 15309               0                 21059    ...
# 15310               0                 21059    ...
# 15311               0                 21059    ...
# 15312               0                  4742    ...
# 15313               0                  4742    ...
# 15314               0                  4742    ...
# 15315               0                  4742    ...
# 15316               0                  4742    ...
# 15317               0                  4742    ...
# 15318               0                  4742    ...
# 15319               0                  4539    ...
# 15320               0                  8955    ...
# 15321               0                  8955    ...
# 15322               0                  8955    ...
# 15323               0                  8955    ...
# 15324               0                  7240    ...
# 15325               0                  7240    ...
# 15326               0                  7240    ...
# 15327               0                  7240    ...
# 15328               0                 10249    ...
# 15329               0                 10249    ...
# 15330               0                 10249    ...
# 15331               0                 10249    ...
# 15332               0                 12062    ...
# 15333               0                 12062    ...
# 15334               0                 12062    ...
# 15335               0                 12062    ...
# 15336               0                 12062    ...
# 15337               0                 12062    ...
# 15338               0                 12062    ...
#
#        eelectronics_numactivegtus  eelectronics_gtustart  eelectronics_gtuend  \
# 0                               0                     -1                    0
# 1                               0                     -1                    0
# 2                               0                     -1                    0
# 3                               0                     -1                    0
# 4                               0                     -1                    0
# 5                               0                     -1                    0
# 6                               0                     -1                    0
# 7                               0                     -1                    0
# 8                               0                     -1                    0
# 9                               0                     -1                    0
# 10                              0                     -1                    0
# 11                              0                     -1                    0
# 12                              0                     -1                    0
# 13                     1072298520                     -1                    0
# 14                     1072298520                     -1                    0
# 15                     1072298520                     -1                    0
# 16                     1072298520                     -1                    0
# 17                              0                     -1                    0
# 18                              0                     -1                    0
# 19                              0                     -1                    0
# 20                              0                     -1                    0
# 21                              0                     -1                    0
# 22                              0                     -1                    0
# 23                              0                     -1                    0
# 24                              0                     -1                    0
# 25                              0                     -1                    0
# 26                              0                     -1                    0
# 27                              0                     -1                    0
# 28                              0                     -1                    0
# 29                              0                     -1                    0
# ...                           ...                    ...                  ...
# 15309                           0                     -1                    0
# 15310                           0                     -1                    0
# 15311                           0                     -1                    0
# 15312                           0                     -1                    0
# 15313                           0                     -1                    0
# 15314                           0                     -1                    0
# 15315                           0                     -1                    0
# 15316                           0                     -1                    0
# 15317                           0                     -1                    0
# 15318                           0                     -1                    0
# 15319                           0                     -1                    0
# 15320                           0                     -1                    0
# 15321                           0                     -1                    0
# 15322                           0                     -1                    0
# 15323                           0                     -1                    0
# 15324                           0                     -1                    0
# 15325                           0                     -1                    0
# 15326                           0                     -1                    0
# 15327                           0                     -1                    0
# 15328                           0                     -1                    0
# 15329                           0                     -1                    0
# 15330                           0                     -1                    0
# 15331                           0                     -1                    0
# 15332                  1058542890                     -1                    0
# 15333                  1058542890                     -1                    0
# 15334                  1058542890                     -1                    0
# 15335                  1058542890                     -1                    0
# 15336                  1058542890                     -1                    0
# 15337                  1058542890                     -1                    0
# 15338                  1058542890                     -1                    0
#
#        eelectronics_numcells  eelectronics_timegtu0  \
# 0                          1               143360.0
# 1                          1               143360.0
# 2                          1               143360.0
# 3                          1               143360.0
# 4                          1                97037.3
# 5                          1                97037.3
# 6                          1                97037.3
# 7                          1                97037.3
# 8                          1               246429.0
# 9                          1               246429.0
# 10                         1               246429.0
# 11                         1               246429.0
# 12                         1               246429.0
# 13                         1               338944.0
# 14                         1               338944.0
# 15                         1               338944.0
# 16                         1               338944.0
# 17                         1               295022.0
# 18                         1               160851.0
# 19                         1               160851.0
# 20                         1               160851.0
# 21                         1               160851.0
# 22                         1               117816.0
# 23                         1               117816.0
# 24                         1               117816.0
# 25                         1               117816.0
# 26                         1               104485.0
# 27                         1               190427.0
# 28                         1               190427.0
# 29                         1               190427.0
# ...                      ...                    ...
# 15309                      1               208060.0
# 15310                      1               208060.0
# 15311                      1               208060.0
# 15312                      1               111894.0
# 15313                      1               111894.0
# 15314                      1               111894.0
# 15315                      1               111894.0
# 15316                      1               111894.0
# 15317                      1               111894.0
# 15318                      1               111894.0
# 15319                      1               102735.0
# 15320                      1               143324.0
# 15321                      1               143324.0
# 15322                      1               143324.0
# 15323                      1               143324.0
# 15324                      1               188691.0
# 15325                      1               188691.0
# 15326                      1               188691.0
# 15327                      1               188691.0
# 15328                      1               379578.0
# 15329                      1               379578.0
# 15330                      1               379578.0
# 15331                      1               379578.0
# 15332                      1               168192.0
# 15333                      1               168192.0
# 15334                      1               168192.0
# 15335                      1               168192.0
# 15336                      1               168192.0
# 15337                      1               168192.0
# 15338                      1               168192.0
#
#        eelectronics_timefirstgtu  eelectronics_timelastgtu  \
# 0                   5.368710e+12             -1.000000e+20
# 1                   5.368710e+12             -1.000000e+20
# 2                   5.368710e+12             -1.000000e+20
# 3                   5.368710e+12             -1.000000e+20
# 4                   5.368710e+12             -1.000000e+20
# 5                   5.368710e+12             -1.000000e+20
# 6                   5.368710e+12             -1.000000e+20
# 7                   5.368710e+12             -1.000000e+20
# 8                   5.368710e+12             -1.000000e+20
# 9                   5.368710e+12             -1.000000e+20
# 10                  5.368710e+12             -1.000000e+20
# 11                  5.368710e+12             -1.000000e+20
# 12                  5.368710e+12             -1.000000e+20
# 13                  5.368710e+12             -1.000000e+20
# 14                  5.368710e+12             -1.000000e+20
# 15                  5.368710e+12             -1.000000e+20
# 16                  5.368710e+12             -1.000000e+20
# 17                  5.368710e+12             -1.000000e+20
# 18                  5.368710e+12             -1.000000e+20
# 19                  5.368710e+12             -1.000000e+20
# 20                  5.368710e+12             -1.000000e+20
# 21                  5.368710e+12             -1.000000e+20
# 22                  5.368710e+12             -1.000000e+20
# 23                  5.368710e+12             -1.000000e+20
# 24                  5.368710e+12             -1.000000e+20
# 25                  5.368710e+12             -1.000000e+20
# 26                  5.368710e+12             -1.000000e+20
# 27                  5.368710e+12             -1.000000e+20
# 28                  5.368710e+12             -1.000000e+20
# 29                  5.368710e+12             -1.000000e+20
# ...                          ...                       ...
# 15309               5.368710e+12             -1.000000e+20
# 15310               5.368710e+12             -1.000000e+20
# 15311               5.368710e+12             -1.000000e+20
# 15312               5.368710e+12             -1.000000e+20
# 15313               5.368710e+12             -1.000000e+20
# 15314               5.368710e+12             -1.000000e+20
# 15315               5.368710e+12             -1.000000e+20
# 15316               5.368710e+12             -1.000000e+20
# 15317               5.368710e+12             -1.000000e+20
# 15318               5.368710e+12             -1.000000e+20
# 15319               5.368710e+12             -1.000000e+20
# 15320               5.368710e+12             -1.000000e+20
# 15321               5.368710e+12             -1.000000e+20
# 15322               5.368710e+12             -1.000000e+20
# 15323               5.368710e+12             -1.000000e+20
# 15324               5.368710e+12             -1.000000e+20
# 15325               5.368710e+12             -1.000000e+20
# 15326               5.368710e+12             -1.000000e+20
# 15327               5.368710e+12             -1.000000e+20
# 15328               5.368710e+12             -1.000000e+20
# 15329               5.368710e+12             -1.000000e+20
# 15330               5.368710e+12             -1.000000e+20
# 15331               5.368710e+12             -1.000000e+20
# 15332               5.368710e+12             -1.000000e+20
# 15333               5.368710e+12             -1.000000e+20
# 15334               5.368710e+12             -1.000000e+20
# 15335               5.368710e+12             -1.000000e+20
# 15336               5.368710e+12             -1.000000e+20
# 15337               5.368710e+12             -1.000000e+20
# 15338               5.368710e+12             -1.000000e+20
#
#        eelectronics_gtulength  relation_id  event_id
# 0                      2500.0            1    992930
# 1                      2500.0            2    992931
# 2                      2500.0            3    992932
# 3                      2500.0            4    992933
# 4                      2500.0            5    992934
# 5                      2500.0            6    992935
# 6                      2500.0            7    992936
# 7                      2500.0            8    992937
# 8                      2500.0            9    992938
# 9                      2500.0           10    992939
# 10                     2500.0           11    992940
# 11                     2500.0           12    992941
# 12                     2500.0           13    992942
# 13                     2500.0           14    992943
# 14                     2500.0           15    992944
# 15                     2500.0           16    992945
# 16                     2500.0           17    992946
# 17                     2500.0           18    992947
# 18                     2500.0           19    992948
# 19                     2500.0           20    992949
# 20                     2500.0           21    992950
# 21                     2500.0           22    992951
# 22                     2500.0           23    992952
# 23                     2500.0           24    992953
# 24                     2500.0           25    992954
# 25                     2500.0           26    992955
# 26                     2500.0           27    992956
# 27                     2500.0           28    992957
# 28                     2500.0           29    992958
# 29                     2500.0           30    992959
# ...                       ...          ...       ...
# 15309                  2500.0        15310   1008240
# 15310                  2500.0        15311   1008241
# 15311                  2500.0        15312   1008242
# 15312                  2500.0        15313   1008243
# 15313                  2500.0        15314   1008244
# 15314                  2500.0        15315   1008245
# 15315                  2500.0        15316   1008246
# 15316                  2500.0        15317   1008247
# 15317                  2500.0        15318   1008248
# 15318                  2500.0        15319   1008249
# 15319                  2500.0        15320   1008250
# 15320                  2500.0        15321   1008251
# 15321                  2500.0        15322   1008252
# 15322                  2500.0        15323   1008253
# 15323                  2500.0        15324   1008254
# 15324                  2500.0        15325   1008255
# 15325                  2500.0        15326   1008256
# 15326                  2500.0        15327   1008257
# 15327                  2500.0        15328   1008258
# 15328                  2500.0        15329   1008259
# 15329                  2500.0        15330   1008260
# 15330                  2500.0        15331   1008261
# 15331                  2500.0        15332   1008262
# 15332                  2500.0        15333   1008263
# 15333                  2500.0        15334   1008264
# 15334                  2500.0        15335   1008265
# 15335                  2500.0        15336   1008266
# 15336                  2500.0        15337   1008267
# 15337                  2500.0        15338   1008268
# 15338                  2500.0        15339   1008269
#
# [15339 rows x 98 columns]

# %%
simu_events['etruth_trueenergy'].hist()

# %%
plt.show()

# %%
simu_events['etruth_trueenergy'][ simu_events['etruth_trueenergy'] > 0.6e13 ].hist()

# %%
plt.show()

# %%
r = simu_events['edetector_numfee'].hist()
r.set_yscale('log')

# %%
plt.show()

# %%
# simu_events['edetector_numfee'] < 50000
trigg_events = simu_events[ simu_events['eptttrigger_eptttriggersegment_0_numevt'].notnull() ][['event_id','edetector_numfee','simu2npy_pathname','etruth_trueenergy','etruth_truetheta','eptttrigger_eptttriggersegment_0_numevt']].sort_values(['edetector_numfee'],ascending=[1])
trigg_events
# Out:
#        event_id  edetector_numfee  \
# 7524    1000454              4288
# 1956     994886              6355
# 1960     994890              6355
# 1962     994892              6355
# 1952     994882              6355
# 7330    1000260              7566
# 7334    1000264              7566
# 7339    1000269              7566
# 7343    1000273              7566
# 7347    1000277              7566
# 8423    1001353              8508
# 13689   1006620              9625
# 13687   1006618              9625
# 9193    1002123              9638
# 14730   1007661              9700
# 5075     998005              9729
# 3711     996641              9751
# 3706     996636              9751
# 3744     996674              9751
# 3730     996660              9751
# 3723     996653              9751
# 3717     996647              9751
# 3737     996667              9751
# 12330   1005261             10597
# 6838     999768             10671
# 13478   1006409             10754
# 3472     996402             10818
# 3476     996406             10818
# 3480     996410             10818
# 3468     996398             10818
# ...         ...               ...
# 14588   1007519             64188
# 15064   1007995             64412
# 14700   1007631             64523
# 14541   1007472             65566
# 12549   1005480             67587
# 14713   1007644             68365
# 14986   1007917             68828
# 9638    1002568             68913
# 9447    1002377             69788
# 12681   1005612             72860
# 10185   1003115             74168
# 9794    1002724             78138
# 7573    1000503             79240
# 2665     995595             82453
# 5321     998251             86542
# 15058   1007989             93342
# 10012   1002942             95264
# 14556   1007487             95498
# 14858   1007789             96474
# 5555     998485             97416
# 9688    1002618            103898
# 9686    1002616            103898
# 9690    1002620            103898
# 9692    1002622            103898
# 6883     999813            111432
# 14837   1007768            113759
# 7320    1000250            113919
# 122      993052            156278
# 9696    1002626            162918
# 11552   1004483            210524
#
#                                        simu2npy_pathname  etruth_trueenergy  \
# 7524   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
# 1956   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 1960   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 1962   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 1952   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 7330   /media/node15_data2/SPBDATA_processed/spb_simu...       2.400000e+12
# 7334   /media/node15_data2/SPBDATA_processed/spb_simu...       2.400000e+12
# 7339   /media/node15_data2/SPBDATA_processed/spb_simu...       2.400000e+12
# 7343   /media/node15_data2/SPBDATA_processed/spb_simu...       2.400000e+12
# 7347   /media/node15_data2/SPBDATA_processed/spb_simu...       2.400000e+12
# 8423   /media/node15_data2/SPBDATA_processed/spb_simu...       3.250000e+12
# 13689  /media/node15_data2/SPBDATA_processed/spb_simu...       5.011870e+12
# 13687  /media/node15_data2/SPBDATA_processed/spb_simu...       5.011870e+12
# 9193   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       5.011870e+12
# 14730  /media/node15_data2/SPBDATA_processed/spb_simu...       5.950000e+12
# 5075   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.548130e+12
# 3711   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 3706   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 3744   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 3730   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 3723   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 3717   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 3737   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 12330  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       5.623410e+12
# 6838   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 13478  /media/node15_data2/SPBDATA_processed/spb_simu...       2.100000e+12
# 3472   /media/node15_data2/SPBDATA_processed/spb_simu...       1.778280e+12
# 3476   /media/node15_data2/SPBDATA_processed/spb_simu...       1.778280e+12
# 3480   /media/node15_data2/SPBDATA_processed/spb_simu...       1.778280e+12
# 3468   /media/node15_data2/SPBDATA_processed/spb_simu...       1.778280e+12
# ...                                                  ...                ...
# 14588  /media/node15_data2/SPBDATA_processed/spb_simu...       8.500000e+12
# 15064  /media/node15_data2/SPBDATA_processed/spb_simu...       3.940000e+12
# 14700  /media/node15_data2/SPBDATA_processed/spb_simu...       5.950000e+12
# 14541  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 12549  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       5.623410e+12
# 14713  /media/node15_data2/SPBDATA_processed/spb_simu...       5.950000e+12
# 14986  /media/node15_data2/SPBDATA_processed/spb_simu...       6.850000e+12
# 9638   /media/node15_data2/SPBDATA_processed/spb_simu...       3.162280e+12
# 9447   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 12681  /media/node15_data2/SPBDATA_processed/spb_simu...       6.900000e+12
# 10185  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 9794   /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 7573   /media/node15_data2/SPBDATA_processed/spb_simu...       5.500000e+12
# 2665   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 5321   /media/node15_data2/SPBDATA_processed/spb_simu...       1.995260e+12
# 15058  /media/node15_data2/SPBDATA_processed/spb_simu...       3.940000e+12
# 10012  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       5.623410e+12
# 14556  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 14858  /media/node15_data2/SPBDATA_processed/spb_simu...       6.400000e+12
# 5555   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.548130e+12
# 9688   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 9686   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 9690   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 9692   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 6883   /media/node15_data2/SPBDATA_processed/spb_simu...       5.500000e+12
# 14837  /media/node15_data2/SPBDATA_processed/spb_simu...       8.500000e+12
# 7320   /media/node15_data2/SPBDATA_processed/spb_simu...       3.162280e+12
# 122    /media/node15_data2/SPBDATA_processed/spb_simu...       3.000000e+12
# 9696   /media/node15_data2/SPBDATA_processed/spb_simu...       5.460000e+12
# 11552  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
#
#        etruth_truetheta  eptttrigger_eptttriggersegment_0_numevt
# 7524           0.401234                                     48.0
# 1956           0.401234                                     48.0
# 1960           0.401234                                     48.0
# 1962           0.401234                                     48.0
# 1952           0.401234                                     48.0
# 7330           0.426427                                     25.0
# 7334           0.426427                                     25.0
# 7339           0.426427                                     25.0
# 7343           0.426427                                     25.0
# 7347           0.426427                                     25.0
# 8423           0.678430                                     45.0
# 13689          0.259330                                     62.0
# 13687          0.259330                                     62.0
# 9193           0.371289                                     81.0
# 14730          0.052016                                      7.0
# 5075           0.766463                                     65.0
# 3711           0.371289                                     81.0
# 3706           0.371289                                     81.0
# 3744           0.371289                                     81.0
# 3730           0.371289                                     81.0
# 3723           0.371289                                     81.0
# 3717           0.371289                                     81.0
# 3737           0.371289                                     81.0
# 12330          0.053622                                     79.0
# 6838           0.681736                                     40.0
# 13478          1.406830                                     49.0
# 3472           1.406830                                     49.0
# 3476           1.406830                                     49.0
# 3480           1.406830                                     49.0
# 3468           1.406830                                     49.0
# ...                 ...                                      ...
# 14588          0.956047                                      9.0
# 15064          1.224290                                      7.0
# 14700          1.280030                                     41.0
# 14541          1.158270                                     14.0
# 12549          1.183680                                     10.0
# 14713          1.303070                                     84.0
# 14986          1.303070                                     84.0
# 9638           1.371050                                     33.0
# 9447           1.183680                                     10.0
# 12681          1.158270                                     14.0
# 10185          1.039900                                     79.0
# 9794           1.336580                                      0.0
# 7573           1.311530                                      8.0
# 2665           1.375190                                      2.0
# 5321           1.224290                                      7.0
# 15058          1.371050                                     33.0
# 10012          1.406830                                     49.0
# 14556          1.274240                                     83.0
# 14858          1.407880                                     49.0
# 5555           1.371050                                     33.0
# 9688           1.371050                                     33.0
# 9686           1.371050                                     33.0
# 9690           1.371050                                     33.0
# 9692           1.371050                                     33.0
# 6883           1.406830                                     49.0
# 14837          1.274240                                     83.0
# 7320           1.371050                                     33.0
# 122            1.371050                                     33.0
# 9696           1.336580                                      0.0
# 11552          1.406830                                     49.0
#
# [3913 rows x 6 columns]

# %%
test_ev = trigg_events.iloc[0]
frames_first_trigg_event_signals = np.load(glob.glob(test_ev.simu2npy_pathname[:-9]+'*signals.npy')[0])
frames_first_trigg_event_counts = np.load(glob.glob(test_ev.simu2npy_pathname[:-9]+'*counts.npy')[0])
print("Energy of the visualized event: {} MeV; Zenith angle: {} deg".format(test_ev.etruth_trueenergy, np.rad2deg(test_ev.etruth_truetheta)))
# Out:
# Energy of the visualized event: 4466840000000.0 MeV; Zenith angle: 22.989014797152073 deg

# %%
fig, axs = plt.subplots(1,2)
npy_vis.visualize_frame(np.maximum.reduce(frames_first_trigg_event_signals), ax=axs[0], show=False)
npy_vis.visualize_frame(np.maximum.reduce(frames_first_trigg_event_counts), ax=axs[1])
# Out:
# (<matplotlib.figure.Figure at 0x7f96b04f4668>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f972e1d4f98>)

# %%
r = trigg_events['edetector_numfee'].hist()
r.set_yscale('log')
plt.show()
print(len(trigg_events['edetector_numfee']))
# Out:
# 3913

# %%
r = simu_events['edetector_numfee'].hist()
r.set_yscale('log')
plt.show()
print(len(simu_events['edetector_numfee']))
# Out:
# 15339

# %%
fee_events = simu_events[ simu_events['edetector_numfee']>30000 ][['event_id','edetector_numfee','simu2npy_pathname','etruth_trueenergy','etruth_truetheta','eptttrigger_eptttriggersegment_0_numevt']].sort_values(['edetector_numfee'],ascending=[1])
fee_events
# Out:
#        event_id  edetector_numfee  \
# 1302     994232             30001
# 1307     994237             30001
# 2545     995475             30003
# 2525     995455             30003
# 2554     995484             30003
# 2550     995480             30003
# 2530     995460             30003
# 2540     995470             30003
# 2535     995465             30003
# 8338    1001268             30004
# 3176     996106             30005
# 9246    1002176             30007
# 9243    1002173             30007
# 9240    1002170             30007
# 9249    1002179             30007
# 9484    1002414             30008
# 2283     995213             30009
# 2493     995423             30009
# 2287     995217             30009
# 2279     995209             30009
# 2292     995222             30009
# 3402     996332             30010
# 7486    1000416             30010
# 9779    1002709             30012
# 4116     997046             30013
# 4099     997029             30013
# 4103     997033             30013
# 4107     997037             30013
# 4110     997040             30013
# 4113     997043             30013
# ...         ...               ...
# 12041   1004972            103798
# 12043   1004974            103798
# 12029   1004960            103798
# 12039   1004970            103798
# 9690    1002620            103898
# 9688    1002618            103898
# 9692    1002622            103898
# 9686    1002616            103898
# 6883     999813            111432
# 14567   1007498            111435
# 14568   1007499            111435
# 14569   1007500            111435
# 14570   1007501            111435
# 14837   1007768            113759
# 7320    1000250            113919
# 10745   1003675            114662
# 10748   1003678            114662
# 10749   1003679            114662
# 10746   1003676            114662
# 6521     999451            130724
# 6536     999466            130724
# 6532     999462            130724
# 6526     999456            130724
# 179      993109            146632
# 177      993107            146632
# 175      993105            146632
# 172      993102            146632
# 122      993052            156278
# 9696    1002626            162918
# 11552   1004483            210524
#
#                                        simu2npy_pathname  etruth_trueenergy  \
# 1302   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 1307   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 2545   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 2525   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 2554   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 2550   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 2530   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 2540   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 2535   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 8338   /media/node15_data2/SPBDATA_processed/spb_simu...       5.300000e+12
# 3176   /media/node15_data2/SPBDATA_processed/spb_simu...       1.900000e+12
# 9246   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 9243   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 9240   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 9249   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 9484   /media/node15_data2/SPBDATA_processed/spb_simu...       5.460000e+12
# 2283   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 2493   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 2287   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 2279   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 2292   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       2.818380e+12
# 3402   /media/node15_data2/SPBDATA_processed/spb_simu...       3.981070e+12
# 7486   /media/node15_data2/SPBDATA_processed/spb_simu...       5.500000e+12
# 9779   /media/node15_data2/SPBDATA_processed/spb_simu...       3.548130e+12
# 4116   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 4099   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 4103   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 4107   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 4110   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# 4113   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.162280e+12
# ...                                                  ...                ...
# 12041  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
# 12043  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
# 12029  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
# 12039  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
# 9690   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 9688   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 9692   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 9686   /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       3.981070e+12
# 6883   /media/node15_data2/SPBDATA_processed/spb_simu...       5.500000e+12
# 14567  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 14568  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 14569  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 14570  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 14837  /media/node15_data2/SPBDATA_processed/spb_simu...       8.500000e+12
# 7320   /media/node15_data2/SPBDATA_processed/spb_simu...       3.162280e+12
# 10745  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 10748  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 10749  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 10746  /media/node15_data2/SPBDATA_processed/spb_simu...       1.000000e+13
# 6521   /media/node15_data2/SPBDATA_processed/spb_simu...       2.818380e+12
# 6536   /media/node15_data2/SPBDATA_processed/spb_simu...       2.818380e+12
# 6532   /media/node15_data2/SPBDATA_processed/spb_simu...       2.818380e+12
# 6526   /media/node15_data2/SPBDATA_processed/spb_simu...       2.818380e+12
# 179    /media/node15_data2/SPBDATA_processed/spb_simu...       1.450000e+12
# 177    /media/node15_data2/SPBDATA_processed/spb_simu...       1.450000e+12
# 175    /media/node15_data2/SPBDATA_processed/spb_simu...       1.450000e+12
# 172    /media/node15_data2/SPBDATA_processed/spb_simu...       1.450000e+12
# 122    /media/node15_data2/SPBDATA_processed/spb_simu...       3.000000e+12
# 9696   /media/node15_data2/SPBDATA_processed/spb_simu...       5.460000e+12
# 11552  /home/eusobg/EUSO-SPB/SPBDATA_processed/spb_si...       4.466840e+12
#
#        etruth_truetheta  eptttrigger_eptttriggersegment_0_numevt
# 1302           0.779997                                     69.0
# 1307           0.779997                                     69.0
# 2545           1.093720                                      NaN
# 2525           1.093720                                      NaN
# 2554           1.093720                                      NaN
# 2550           1.093720                                      NaN
# 2530           1.093720                                      NaN
# 2540           1.093720                                      NaN
# 2535           1.093720                                      NaN
# 8338           0.696797                                     13.0
# 3176           0.926244                                      0.0
# 9246           1.054120                                      NaN
# 9243           1.054120                                      NaN
# 9240           1.054120                                      NaN
# 9249           1.054120                                      NaN
# 9484           0.683886                                     66.0
# 2283           1.126090                                      NaN
# 2493           0.663640                                     65.0
# 2287           1.126090                                      NaN
# 2279           1.126090                                      NaN
# 2292           1.126090                                      NaN
# 3402           1.406830                                     49.0
# 7486           0.190815                                     98.0
# 9779           1.274240                                     83.0
# 4116           1.223810                                      NaN
# 4099           1.223810                                      NaN
# 4103           1.223810                                      NaN
# 4107           1.223810                                      NaN
# 4110           1.223810                                      NaN
# 4113           1.223810                                      NaN
# ...                 ...                                      ...
# 12041          1.346780                                      NaN
# 12043          1.346780                                      NaN
# 12029          1.346780                                      NaN
# 12039          1.346780                                      NaN
# 9690           1.371050                                     33.0
# 9688           1.371050                                     33.0
# 9692           1.371050                                     33.0
# 9686           1.371050                                     33.0
# 6883           1.406830                                     49.0
# 14567          1.187990                                      NaN
# 14568          1.187990                                      NaN
# 14569          1.187990                                      NaN
# 14570          1.187990                                      NaN
# 14837          1.274240                                     83.0
# 7320           1.371050                                     33.0
# 10745          1.327720                                      NaN
# 10748          1.327720                                      NaN
# 10749          1.327720                                      NaN
# 10746          1.327720                                      NaN
# 6521           1.366490                                      NaN
# 6536           1.366490                                      NaN
# 6532           1.366490                                      NaN
# 6526           1.366490                                      NaN
# 179            1.297200                                      NaN
# 177            1.297200                                      NaN
# 175            1.297200                                      NaN
# 172            1.297200                                      NaN
# 122            1.371050                                     33.0
# 9696           1.336580                                      0.0
# 11552          1.406830                                     49.0
#
# [4380 rows x 6 columns]

# %%
test_ev = fee_events.iloc[0]
frames_first_fee_event_signals = np.load(glob.glob(test_ev.simu2npy_pathname[:-9]+'*signals.npy')[0])
frames_first_fee_event_counts = np.load(glob.glob(test_ev.simu2npy_pathname[:-9]+'*counts.npy')[0])
print("Energy of the visualized event: {} MeV; Zenith angle: {} deg".format(test_ev.etruth_trueenergy, np.rad2deg(test_ev.etruth_truetheta)))
# Out:
# Energy of the visualized event: 2818380000000.0 MeV; Zenith angle: 44.690536132865674 deg

# %%
fig, axs = plt.subplots(1,2)
npy_vis.visualize_frame(np.maximum.reduce(frames_first_fee_event_signals), ax=axs[0], show=False)
npy_vis.visualize_frame(np.maximum.reduce(frames_first_fee_event_counts), ax=axs[1])
# Out:
# (<matplotlib.figure.Figure at 0x7f96a239a550>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f96a2316e10>)

# %% [markdown]
# # SQL Queries

# %% [markdown]
# ## All simu events

# %%
# all_simu_events = psql.read_sql(
#     "SELECT tr.*, ts.edetector_numfee, ts.etruth_trueenergy, ts.etruth_truetheta , tp.gtu_in_packet, tp.num_gtu, tp.packet_id, tp.num_triggered_pixels, tp.source_file_acquisition, tp.source_file_trigger FROM simu_event_spb_proc AS tr JOIN spb_processing_event_ver2 AS tp USING(event_id) JOIN simu_event AS ts USING(simu_event_id) ;",
#     con)
all_simu_events_by_energy = psql.read_sql("SELECT COUNT(event_id) AS count_event_id, etruth_trueenergy /*, etruth_truetheta*/ FROM simu_event_spb_proc JOIN simu_event USING(simu_event_id) GROUP BY etruth_trueenergy ORDER BY etruth_trueenergy ASC", con)
all_simu_events_by_theta = psql.read_sql("SELECT COUNT(event_id) AS count_event_id, /*etruth_trueenergy ,*/ etruth_truetheta FROM simu_event_spb_proc JOIN simu_event USING(simu_event_id) GROUP BY etruth_truetheta ORDER BY etruth_truetheta ASC", con)

# %%
ax_all_simu_events_by_energy = all_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_event_id',marker='.',linestyle=':')
plt.show()

# %%
all_simu_events_by_theta.plot(x='etruth_truetheta',y='count_event_id',marker='.',linestyle=':')
plt.show()

# %% [markdown]
# ## Number of triggered events in Simu as function of energy

# %%
# all_simu_events = psql.read_sql(
#     "SELECT tr.*, ts.edetector_numfee, ts.etruth_trueenergy, ts.etruth_truetheta , tp.gtu_in_packet, tp.num_gtu, tp.packet_id, tp.num_triggered_pixels, tp.source_file_acquisition, tp.source_file_trigger FROM simu_event_spb_proc AS tr JOIN spb_processing_event_ver2 AS tp USING(event_id) JOIN simu_event AS ts USING(simu_event_id) ;",
#     con)
strg_simu_events_by_energy = psql.read_sql("SELECT COUNT(event_id) AS count_event_id, etruth_trueenergy /*, etruth_truetheta*/ FROM simu_event_spb_proc JOIN simu_event USING(simu_event_id) WHERE eptttrigger_eptttriggersegment_0_numevt IS NOT NULL GROUP BY etruth_trueenergy ORDER BY etruth_trueenergy ASC", con)
strg_simu_events_by_theta = psql.read_sql("SELECT COUNT(event_id) AS count_event_id, /*etruth_trueenergy ,*/ etruth_truetheta FROM simu_event_spb_proc JOIN simu_event USING(simu_event_id) WHERE eptttrigger_eptttriggersegment_0_numevt IS NOT NULL GROUP BY etruth_truetheta ORDER BY etruth_truetheta ASC", con)

# %%
ax_all_simu_events_by_energy = all_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_event_id',marker='.',linestyle=':')
strg_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_event_id',marker='.',linestyle=':', color='red', ax=ax_all_simu_events_by_energy)
plt.show()

# %%
#strg_simu_events_by_energy
strg_all_merged = pd.merge(strg_simu_events_by_energy, all_simu_events_by_energy,
                                    how='outer',
                                    suffixes=['_strg','_all'],
                                    on=['etruth_trueenergy'])
strg_all_merged
# Out:
#     count_event_id_strg  etruth_trueenergy  count_event_id_all
# 0                   5.0       5.000000e+11                 275
# 1                   6.0       9.000000e+11                  50
# 2                   6.0       9.750000e+11                 111
# 3                   8.0       1.000000e+12                 132
# 4                  25.0       1.100000e+12                  89
# 5                  79.0       1.450000e+12                 624
# 6                  11.0       1.500000e+12                  68
# 7                  16.0       1.700000e+12                  69
# 8                  42.0       1.778280e+12                 335
# 9                  50.0       1.900000e+12                 254
# 10                 33.0       1.925000e+12                 165
# 11                 31.0       1.995260e+12                 140
# 12                 18.0       2.000000e+12                  50
# 13                 16.0       2.100000e+12                  17
# 14                 26.0       2.238720e+12                 135
# 15                 17.0       2.300000e+12                  37
# 16                 57.0       2.350000e+12                 233
# 17                 26.0       2.400000e+12                 131
# 18                 39.0       2.420000e+12                  47
# 19                 26.0       2.500000e+12                  56
# 20                 15.0       2.511890e+12                  88
# 21                 47.0       2.800000e+12                 161
# 22                349.0       2.818380e+12                1921
# 23                 15.0       2.875000e+12                  81
# 24                 16.0       2.900000e+12                  80
# 25                 39.0       3.000000e+12                 167
# 26                333.0       3.162280e+12                1525
# 27                 49.0       3.250000e+12                 154
# 28                 14.0       3.350000e+12                  75
# 29                 46.0       3.500000e+12                 120
# 30                287.0       3.548130e+12                1348
# 31                 82.0       3.700000e+12                 201
# 32                  5.0       3.825000e+12                  22
# 33                 43.0       3.940000e+12                  56
# 34                304.0       3.981070e+12                1121
# 35                 56.0       4.150000e+12                 119
# 36                 10.0       4.300000e+12                  39
# 37                321.0       4.466840e+12                1323
# 38                 46.0       4.600000e+12                 113
# 39                  7.0       4.775000e+12                  31
# 40                265.0       5.011870e+12                1096
# 41                 43.0       5.050000e+12                  69
# 42                  2.0       5.250000e+12                  10
# 43                 19.0       5.300000e+12                  51
# 44                 33.0       5.460000e+12                  81
# 45                137.0       5.500000e+12                 311
# 46                309.0       5.623410e+12                1030
# 47                  3.0       5.725000e+12                  15
# 48                 39.0       5.950000e+12                  46
# 49                  7.0       6.200000e+12                   7
# 50                 50.0       6.400000e+12                  97
# 51                 58.0       6.850000e+12                  97
# 52                 30.0       6.900000e+12                  59
# 53                 37.0       6.980000e+12                  54
# 54                 51.0       7.300000e+12                  97
# 55                 78.0       8.500000e+12                 128
# 56                131.0       1.000000e+13                 324
# 57                  NaN       6.675000e+12                   4

# %%
strg_all_merged_nona = strg_all_merged.dropna().copy()
strg_all_merged_nona['count_fraction'] = strg_all_merged_nona['count_event_id_strg'] / strg_all_merged_nona['count_event_id_all']
strg_all_merged_nona
# Out:
#     count_event_id_strg  etruth_trueenergy  count_event_id_all  count_fraction
# 0                   5.0       5.000000e+11                 275        0.018182
# 1                   6.0       9.000000e+11                  50        0.120000
# 2                   6.0       9.750000e+11                 111        0.054054
# 3                   8.0       1.000000e+12                 132        0.060606
# 4                  25.0       1.100000e+12                  89        0.280899
# 5                  79.0       1.450000e+12                 624        0.126603
# 6                  11.0       1.500000e+12                  68        0.161765
# 7                  16.0       1.700000e+12                  69        0.231884
# 8                  42.0       1.778280e+12                 335        0.125373
# 9                  50.0       1.900000e+12                 254        0.196850
# 10                 33.0       1.925000e+12                 165        0.200000
# 11                 31.0       1.995260e+12                 140        0.221429
# 12                 18.0       2.000000e+12                  50        0.360000
# 13                 16.0       2.100000e+12                  17        0.941176
# 14                 26.0       2.238720e+12                 135        0.192593
# 15                 17.0       2.300000e+12                  37        0.459459
# 16                 57.0       2.350000e+12                 233        0.244635
# 17                 26.0       2.400000e+12                 131        0.198473
# 18                 39.0       2.420000e+12                  47        0.829787
# 19                 26.0       2.500000e+12                  56        0.464286
# 20                 15.0       2.511890e+12                  88        0.170455
# 21                 47.0       2.800000e+12                 161        0.291925
# 22                349.0       2.818380e+12                1921        0.181676
# 23                 15.0       2.875000e+12                  81        0.185185
# 24                 16.0       2.900000e+12                  80        0.200000
# 25                 39.0       3.000000e+12                 167        0.233533
# 26                333.0       3.162280e+12                1525        0.218361
# 27                 49.0       3.250000e+12                 154        0.318182
# 28                 14.0       3.350000e+12                  75        0.186667
# 29                 46.0       3.500000e+12                 120        0.383333
# 30                287.0       3.548130e+12                1348        0.212908
# 31                 82.0       3.700000e+12                 201        0.407960
# 32                  5.0       3.825000e+12                  22        0.227273
# 33                 43.0       3.940000e+12                  56        0.767857
# 34                304.0       3.981070e+12                1121        0.271186
# 35                 56.0       4.150000e+12                 119        0.470588
# 36                 10.0       4.300000e+12                  39        0.256410
# 37                321.0       4.466840e+12                1323        0.242630
# 38                 46.0       4.600000e+12                 113        0.407080
# 39                  7.0       4.775000e+12                  31        0.225806
# 40                265.0       5.011870e+12                1096        0.241788
# 41                 43.0       5.050000e+12                  69        0.623188
# 42                  2.0       5.250000e+12                  10        0.200000
# 43                 19.0       5.300000e+12                  51        0.372549
# 44                 33.0       5.460000e+12                  81        0.407407
# 45                137.0       5.500000e+12                 311        0.440514
# 46                309.0       5.623410e+12                1030        0.300000
# 47                  3.0       5.725000e+12                  15        0.200000
# 48                 39.0       5.950000e+12                  46        0.847826
# 49                  7.0       6.200000e+12                   7        1.000000
# 50                 50.0       6.400000e+12                  97        0.515464
# 51                 58.0       6.850000e+12                  97        0.597938
# 52                 30.0       6.900000e+12                  59        0.508475
# 53                 37.0       6.980000e+12                  54        0.685185
# 54                 51.0       7.300000e+12                  97        0.525773
# 55                 78.0       8.500000e+12                 128        0.609375
# 56                131.0       1.000000e+13                 324        0.404321

# %%
strg_all_merged_nona.plot(x='etruth_trueenergy', y='count_fraction', marker='.',linestyle=':', color='purple')
plt.show()

# %% [markdown]
# ## Number of recognized triggered Simu events as function of energy

# %%
cond_simu_events_by_energy = psql.read_sql(
    "SELECT COUNT(event_id) AS count_event_id, etruth_trueenergy " \
    "FROM simu_event_spb_proc "\
    "JOIN simu_event USING(simu_event_id) "\
    "JOIN spb_processing_event_ver2 USING(event_id) "\
    "WHERE eptttrigger_eptttriggersegment_0_numevt IS NOT NULL "\
    "AND num_gtu BETWEEN 12 AND 40 " \
    "AND num_triggered_pixels > 10 " \
    "AND max_n_persist > 4 " \
    "AND (abs(gtu_y_hough__peak_thr2_avg_phi) > 0.174533 OR abs(gtu_x_hough__peak_thr2_avg_phi) > 0.174533) " \
    "AND num_triggered_pixels < 800 " \
    "AND trigg_x_y_hough__peak_thr1__max_cluster_counts_sum_width < 15 " \
    "AND trigg_gtu_x_hough__peak_thr1__max_cluster_counts_sum_width < 41 " \
    "AND trigg_gtu_y_hough__peak_thr1__max_cluster_counts_sum_width < 41 " \
    "AND x_y_hough__peak_thr1__max_cluster_counts_sum_width < 25 " \
    "AND trigg_gtu_y_hough__peak_thr2__max_cluster_counts_sum_width < 20 " \
    "AND trigg_gtu_y_hough__peak_thr2__max_cluster_counts_sum_height < 20 " \
    "AND trigg_gtu_x_hough__peak_thr2__max_cluster_counts_sum_width < 20 " \
    "AND trigg_gtu_x_hough__peak_thr2__max_cluster_counts_sum_height < 20 " \
    "AND gtu_y_hough__dbscan_num_clusters_above_thr1 < 4 " \
    "AND gtu_x_hough__dbscan_num_clusters_above_thr1 < 4 " \
    "AND trigg_x_y_hough__dbscan_num_clusters_above_thr1 < 4 " \
    "AND ( abs(gtu_y_hough__peak_thr3_avg_phi) NOT BETWEEN 1.48353 " \
    "AND 1.65806 OR abs(gtu_x_hough__peak_thr3_avg_phi) NOT BETWEEN 1.48353 AND 1.65806 ) " \
    "AND trigg_gtu_y_hough__dbscan_num_clusters_above_thr1 < 3 " \
    "AND trigg_gtu_x_hough__dbscan_num_clusters_above_thr1 < 3 " \
    "AND gtu_y_hough__peak_thr1__max_cluster_counts_sum_width < 41 " \
    "AND gtu_x_hough__peak_thr1__max_cluster_counts_sum_width < 41" \
    "GROUP BY etruth_trueenergy "\
    "ORDER BY etruth_trueenergy ASC", con)

#strg_simu_events_by_theta = psql.read_sql("SELECT COUNT(event_id) AS count_event_id, /*etruth_trueenergy ,*/ etruth_truetheta FROM simu_event_spb_proc JOIN simu_event USING(simu_event_id) WHERE eptttrigger_eptttriggersegment_0_numevt IS NOT NULL GROUP BY etruth_truetheta ORDER BY etruth_truetheta ASC", con)

# %%
cond_simu_events_by_energy
# Out:
#     count_event_id  etruth_trueenergy
# 0                2       1.700000e+12
# 1                1       1.778280e+12
# 2                1       1.900000e+12
# 3                1       1.925000e+12
# 4                4       1.995260e+12
# 5                4       2.100000e+12
# 6                4       2.238720e+12
# 7                4       2.300000e+12
# 8                6       2.350000e+12
# 9                5       2.400000e+12
# 10               9       2.420000e+12
# 11               4       2.511890e+12
# 12              12       2.800000e+12
# 13              25       2.818380e+12
# 14               5       2.875000e+12
# 15               5       2.900000e+12
# 16               6       3.000000e+12
# 17              31       3.162280e+12
# 18               9       3.250000e+12
# 19               6       3.350000e+12
# 20              13       3.500000e+12
# 21              38       3.548130e+12
# 22              27       3.700000e+12
# 23               1       3.825000e+12
# 24              19       3.940000e+12
# 25              42       3.981070e+12
# 26              13       4.150000e+12
# 27               2       4.300000e+12
# 28              53       4.466840e+12
# 29              13       4.600000e+12
# 30               2       4.775000e+12
# 31              62       5.011870e+12
# 32              10       5.050000e+12
# 33               1       5.250000e+12
# 34               8       5.300000e+12
# 35              15       5.460000e+12
# 36              49       5.500000e+12
# 37              74       5.623410e+12
# 38               1       5.725000e+12
# 39              11       5.950000e+12
# 40               2       6.200000e+12
# 41              16       6.400000e+12
# 42              16       6.850000e+12
# 43              15       6.900000e+12
# 44              18       6.980000e+12
# 45              12       7.300000e+12
# 46              39       8.500000e+12
# 47              63       1.000000e+13

# %%
ax_all_simu_events_by_energy = all_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_event_id',marker='.',linestyle=':')
strg_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_event_id',marker='.',linestyle=':', color='red', ax=ax_all_simu_events_by_energy)
cond_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_event_id',marker='.',linestyle=':', color='green', ax=ax_all_simu_events_by_energy)
plt.show()

# %%
cond_strg_merged = pd.merge(cond_simu_events_by_energy, strg_simu_events_by_energy,
                                    how='outer',
                                    suffixes=['_cond','_strg'],
                                    on=['etruth_trueenergy'])
cond_strg_merged
# Out:
#     count_event_id_cond  etruth_trueenergy  count_event_id_strg
# 0                   2.0       1.700000e+12                   16
# 1                   1.0       1.778280e+12                   42
# 2                   1.0       1.900000e+12                   50
# 3                   1.0       1.925000e+12                   33
# 4                   4.0       1.995260e+12                   31
# 5                   4.0       2.100000e+12                   16
# 6                   4.0       2.238720e+12                   26
# 7                   4.0       2.300000e+12                   17
# 8                   6.0       2.350000e+12                   57
# 9                   5.0       2.400000e+12                   26
# 10                  9.0       2.420000e+12                   39
# 11                  4.0       2.511890e+12                   15
# 12                 12.0       2.800000e+12                   47
# 13                 25.0       2.818380e+12                  349
# 14                  5.0       2.875000e+12                   15
# 15                  5.0       2.900000e+12                   16
# 16                  6.0       3.000000e+12                   39
# 17                 31.0       3.162280e+12                  333
# 18                  9.0       3.250000e+12                   49
# 19                  6.0       3.350000e+12                   14
# 20                 13.0       3.500000e+12                   46
# 21                 38.0       3.548130e+12                  287
# 22                 27.0       3.700000e+12                   82
# 23                  1.0       3.825000e+12                    5
# 24                 19.0       3.940000e+12                   43
# 25                 42.0       3.981070e+12                  304
# 26                 13.0       4.150000e+12                   56
# 27                  2.0       4.300000e+12                   10
# 28                 53.0       4.466840e+12                  321
# 29                 13.0       4.600000e+12                   46
# 30                  2.0       4.775000e+12                    7
# 31                 62.0       5.011870e+12                  265
# 32                 10.0       5.050000e+12                   43
# 33                  1.0       5.250000e+12                    2
# 34                  8.0       5.300000e+12                   19
# 35                 15.0       5.460000e+12                   33
# 36                 49.0       5.500000e+12                  137
# 37                 74.0       5.623410e+12                  309
# 38                  1.0       5.725000e+12                    3
# 39                 11.0       5.950000e+12                   39
# 40                  2.0       6.200000e+12                    7
# 41                 16.0       6.400000e+12                   50
# 42                 16.0       6.850000e+12                   58
# 43                 15.0       6.900000e+12                   30
# 44                 18.0       6.980000e+12                   37
# 45                 12.0       7.300000e+12                   51
# 46                 39.0       8.500000e+12                   78
# 47                 63.0       1.000000e+13                  131
# 48                  NaN       5.000000e+11                    5
# 49                  NaN       9.000000e+11                    6
# 50                  NaN       9.750000e+11                    6
# 51                  NaN       1.000000e+12                    8
# 52                  NaN       1.100000e+12                   25
# 53                  NaN       1.450000e+12                   79
# 54                  NaN       1.500000e+12                   11
# 55                  NaN       2.000000e+12                   18
# 56                  NaN       2.500000e+12                   26

# %%
cond_strg_merged_nona = cond_strg_merged.dropna().copy()
cond_strg_merged_nona['count_fraction'] = cond_strg_merged_nona['count_event_id_cond'] / cond_strg_merged_nona['count_event_id_strg']
cond_strg_merged_nona
# Out:
#     count_event_id_cond  etruth_trueenergy  count_event_id_strg  \
# 0                   2.0       1.700000e+12                   16
# 1                   1.0       1.778280e+12                   42
# 2                   1.0       1.900000e+12                   50
# 3                   1.0       1.925000e+12                   33
# 4                   4.0       1.995260e+12                   31
# 5                   4.0       2.100000e+12                   16
# 6                   4.0       2.238720e+12                   26
# 7                   4.0       2.300000e+12                   17
# 8                   6.0       2.350000e+12                   57
# 9                   5.0       2.400000e+12                   26
# 10                  9.0       2.420000e+12                   39
# 11                  4.0       2.511890e+12                   15
# 12                 12.0       2.800000e+12                   47
# 13                 25.0       2.818380e+12                  349
# 14                  5.0       2.875000e+12                   15
# 15                  5.0       2.900000e+12                   16
# 16                  6.0       3.000000e+12                   39
# 17                 31.0       3.162280e+12                  333
# 18                  9.0       3.250000e+12                   49
# 19                  6.0       3.350000e+12                   14
# 20                 13.0       3.500000e+12                   46
# 21                 38.0       3.548130e+12                  287
# 22                 27.0       3.700000e+12                   82
# 23                  1.0       3.825000e+12                    5
# 24                 19.0       3.940000e+12                   43
# 25                 42.0       3.981070e+12                  304
# 26                 13.0       4.150000e+12                   56
# 27                  2.0       4.300000e+12                   10
# 28                 53.0       4.466840e+12                  321
# 29                 13.0       4.600000e+12                   46
# 30                  2.0       4.775000e+12                    7
# 31                 62.0       5.011870e+12                  265
# 32                 10.0       5.050000e+12                   43
# 33                  1.0       5.250000e+12                    2
# 34                  8.0       5.300000e+12                   19
# 35                 15.0       5.460000e+12                   33
# 36                 49.0       5.500000e+12                  137
# 37                 74.0       5.623410e+12                  309
# 38                  1.0       5.725000e+12                    3
# 39                 11.0       5.950000e+12                   39
# 40                  2.0       6.200000e+12                    7
# 41                 16.0       6.400000e+12                   50
# 42                 16.0       6.850000e+12                   58
# 43                 15.0       6.900000e+12                   30
# 44                 18.0       6.980000e+12                   37
# 45                 12.0       7.300000e+12                   51
# 46                 39.0       8.500000e+12                   78
# 47                 63.0       1.000000e+13                  131
#
#     count_fraction
# 0         0.125000
# 1         0.023810
# 2         0.020000
# 3         0.030303
# 4         0.129032
# 5         0.250000
# 6         0.153846
# 7         0.235294
# 8         0.105263
# 9         0.192308
# 10        0.230769
# 11        0.266667
# 12        0.255319
# 13        0.071633
# 14        0.333333
# 15        0.312500
# 16        0.153846
# 17        0.093093
# 18        0.183673
# 19        0.428571
# 20        0.282609
# 21        0.132404
# 22        0.329268
# 23        0.200000
# 24        0.441860
# 25        0.138158
# 26        0.232143
# 27        0.200000
# 28        0.165109
# 29        0.282609
# 30        0.285714
# 31        0.233962
# 32        0.232558
# 33        0.500000
# 34        0.421053
# 35        0.454545
# 36        0.357664
# 37        0.239482
# 38        0.333333
# 39        0.282051
# 40        0.285714
# 41        0.320000
# 42        0.275862
# 43        0.500000
# 44        0.486486
# 45        0.235294
# 46        0.500000
# 47        0.480916

# %%
cond_strg_merged_nona.plot(x='etruth_trueenergy', y='count_fraction', marker='.',linestyle=':', color='black')
plt.show()

# %% [markdown]
# # Number of packets

# %%
t_all_bgf05_simu_events_by_energy_query = \
'''
SELECT COUNT(sq.count_event_id) AS count_packets, sq.etruth_trueenergy AS etruth_trueenergy 
FROM (
  SELECT COUNT(dt1.event_id) AS count_event_id, dt1.source_file_acquisition_full, etruth_trueenergy 
  FROM simu_event_spb_proc 
  JOIN simu_event USING(simu_event_id) 
  JOIN spb_processing_event_ver2 AS dt1 USING(event_id) 
  JOIN spb_processing_event_ver2 AS dt2 USING(source_file_acquisition_full) 
  WHERE dt1.source_data_type_num=3 AND dt2.source_data_type_num=5
  GROUP BY etruth_trueenergy, dt1.source_file_acquisition_full, dt1.packet_id
) as sq GROUP BY etruth_trueenergy ORDER BY etruth_trueenergy;
'''

t_all_bgf05_simu_events_by_energy = psql.read_sql( t_all_bgf05_simu_events_by_energy_query   ,con)

# %%
t_all_bgf05_simu_events_by_energy
# Out:
#     count_packets  etruth_trueenergy
# 0               1       9.000000e+11
# 1              11       1.000000e+12
# 2               8       1.100000e+12
# 3              18       1.122020e+12
# 4              20       1.258930e+12
# 5              17       1.412540e+12
# 6              12       1.450000e+12
# 7               8       1.500000e+12
# 8              23       1.584890e+12
# 9               1       1.700000e+12
# 10             27       1.778280e+12
# 11             18       1.900000e+12
# 12              6       1.925000e+12
# 13             23       1.995260e+12
# 14              9       2.000000e+12
# 15              4       2.100000e+12
# 16             40       2.238720e+12
# 17              4       2.300000e+12
# 18             18       2.350000e+12
# 19             10       2.400000e+12
# 20              6       2.420000e+12
# 21             21       2.500000e+12
# 22             34       2.511890e+12
# 23             19       2.800000e+12
# 24             60       2.818380e+12
# 25             62       2.875000e+12
# 26              2       2.900000e+12
# 27             21       3.000000e+12
# 28             45       3.162280e+12
# 29             33       3.250000e+12
# ..            ...                ...
# 38             36       4.150000e+12
# 39             15       4.300000e+12
# 40            111       4.466840e+12
# 41             38       4.600000e+12
# 42             20       4.775000e+12
# 43            114       5.011870e+12
# 44             35       5.050000e+12
# 45             21       5.250000e+12
# 46             13       5.300000e+12
# 47             23       5.460000e+12
# 48             96       5.500000e+12
# 49            120       5.623410e+12
# 50             14       5.725000e+12
# 51            315       5.950000e+12
# 52             15       6.200000e+12
# 53            138       6.309570e+12
# 54             34       6.400000e+12
# 55             17       6.675000e+12
# 56            312       6.850000e+12
# 57             12       6.900000e+12
# 58             16       6.980000e+12
# 59             31       7.000000e+12
# 60            151       7.079460e+12
# 61             40       7.150000e+12
# 62             39       7.300000e+12
# 63            114       7.750000e+12
# 64            117       7.943280e+12
# 65             36       8.500000e+12
# 66            137       8.912510e+12
# 67            438       1.000000e+13
#
# [68 rows x 2 columns]

# %%
t_all_bgf05_simu_events_by_energy.plot(x='etruth_trueenergy', y='count_packets')
plt.show()

# %%
 # NOT VERY IMPORTANT

t_all_bgf10_simu_events_by_energy_query = \
'''
SELECT COUNT(sq.count_event_id) AS count_packets, sq.etruth_trueenergy AS etruth_trueenergy 
FROM (
  SELECT COUNT(dt1.event_id) AS count_event_id, source_file_acquisition,  etruth_trueenergy 
  FROM simu_event_spb_proc 
  JOIN simu_event USING(simu_event_id) 
  JOIN spb_processing_event_ver2 AS dt1 USING(event_id) 
  JOIN spb_processing_event_ver2 AS dt2 USING(source_file_acquisition) 
  WHERE dt1.source_data_type_num=5 AND dt2.source_data_type_num=3
  GROUP BY etruth_trueenergy, source_file_acquisition, dt1.packet_id
) as sq GROUP BY etruth_trueenergy ORDER BY etruth_trueenergy;
'''

t_all_bgf10_simu_events_by_energy = psql.read_sql( t_all_bgf10_simu_events_by_energy_query, con)

# %%
t_all_bgf10_simu_events_by_energy
# Out:
#     count_packets  etruth_trueenergy
# 0               1       1.412540e+12
# 1               2       1.900000e+12
# 2               1       1.995260e+12
# 3               1       2.100000e+12
# 4               2       2.238720e+12
# 5               2       2.300000e+12
# 6               5       2.350000e+12
# 7               3       2.400000e+12
# 8               1       2.420000e+12
# 9               1       2.500000e+12
# 10              4       2.511890e+12
# 11              7       2.800000e+12
# 12             12       2.818380e+12
# 13             35       2.875000e+12
# 14              2       2.900000e+12
# 15              3       3.000000e+12
# 16             10       3.162280e+12
# 17             13       3.250000e+12
# 18              8       3.350000e+12
# 19             10       3.500000e+12
# 20             24       3.548130e+12
# 21             23       3.700000e+12
# 22              7       3.825000e+12
# 23             14       3.940000e+12
# 24             36       3.981070e+12
# 25             16       4.000000e+12
# 26             24       4.150000e+12
# 27              6       4.300000e+12
# 28             52       4.466840e+12
# 29             31       4.600000e+12
# 30             13       4.775000e+12
# 31             69       5.011870e+12
# 32             29       5.050000e+12
# 33             11       5.250000e+12
# 34             12       5.300000e+12
# 35             17       5.460000e+12
# 36             78       5.500000e+12
# 37             86       5.623410e+12
# 38             13       5.725000e+12
# 39            277       5.950000e+12
# 40             16       6.200000e+12
# 41            112       6.309570e+12
# 42             31       6.400000e+12
# 43             17       6.675000e+12
# 44            271       6.850000e+12
# 45             16       6.900000e+12
# 46             21       6.980000e+12
# 47             22       7.000000e+12
# 48            120       7.079460e+12
# 49             36       7.150000e+12
# 50             36       7.300000e+12
# 51             96       7.750000e+12
# 52            112       7.943280e+12
# 53             33       8.500000e+12
# 54            131       8.912510e+12
# 55            296       1.000000e+13

# %%
t_all_bgf10_simu_events_by_energy.plot(x='etruth_trueenergy', y='count_packets')
plt.show()

# %%
ax_all_bgf05_simu_events_by_energy = t_all_bgf05_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_packets',marker='.',linestyle='-',label='Num. packets bgf=0.5')
t_all_bgf10_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_packets',marker='.',linestyle=':', color='red', ax=ax_all_bgf05_simu_events_by_energy, label='Num. packets bgf=1.0')
plt.show()

# %%
# NOT VERY IMPORTANT
t_all_bgf10_simu_events_by_energy_merged = pd.merge(t_all_bgf10_simu_events_by_energy, t_all_bgf05_simu_events_by_energy,
                                    how='outer',
                                    suffixes=['_bgf10','_bgf05'],
                                    on=['etruth_trueenergy'])
t_all_bgf10_simu_events_by_energy_merged_nona = t_all_bgf10_simu_events_by_energy_merged.dropna().copy()
t_all_bgf10_simu_events_by_energy_merged_nona['count_fraction'] = t_all_bgf10_simu_events_by_energy_merged_nona['count_packets_bgf10'] / t_all_bgf10_simu_events_by_energy_merged_nona['count_packets_bgf05']
t_all_bgf10_simu_events_by_energy_merged_nona
# Out:
#     count_packets_bgf10  etruth_trueenergy  count_packets_bgf05  \
# 0                   1.0       1.412540e+12                   17
# 1                   2.0       1.900000e+12                   18
# 2                   1.0       1.995260e+12                   23
# 3                   1.0       2.100000e+12                    4
# 4                   2.0       2.238720e+12                   40
# 5                   2.0       2.300000e+12                    4
# 6                   5.0       2.350000e+12                   18
# 7                   3.0       2.400000e+12                   10
# 8                   1.0       2.420000e+12                    6
# 9                   1.0       2.500000e+12                   21
# 10                  4.0       2.511890e+12                   34
# 11                  7.0       2.800000e+12                   19
# 12                 12.0       2.818380e+12                   60
# 13                 35.0       2.875000e+12                   62
# 14                  2.0       2.900000e+12                    2
# 15                  3.0       3.000000e+12                   21
# 16                 10.0       3.162280e+12                   45
# 17                 13.0       3.250000e+12                   33
# 18                  8.0       3.350000e+12                   12
# 19                 10.0       3.500000e+12                   31
# 20                 24.0       3.548130e+12                   71
# 21                 23.0       3.700000e+12                   46
# 22                  7.0       3.825000e+12                   15
# 23                 14.0       3.940000e+12                   27
# 24                 36.0       3.981070e+12                   77
# 25                 16.0       4.000000e+12                   22
# 26                 24.0       4.150000e+12                   36
# 27                  6.0       4.300000e+12                   15
# 28                 52.0       4.466840e+12                  111
# 29                 31.0       4.600000e+12                   38
# 30                 13.0       4.775000e+12                   20
# 31                 69.0       5.011870e+12                  114
# 32                 29.0       5.050000e+12                   35
# 33                 11.0       5.250000e+12                   21
# 34                 12.0       5.300000e+12                   13
# 35                 17.0       5.460000e+12                   23
# 36                 78.0       5.500000e+12                   96
# 37                 86.0       5.623410e+12                  120
# 38                 13.0       5.725000e+12                   14
# 39                277.0       5.950000e+12                  315
# 40                 16.0       6.200000e+12                   15
# 41                112.0       6.309570e+12                  138
# 42                 31.0       6.400000e+12                   34
# 43                 17.0       6.675000e+12                   17
# 44                271.0       6.850000e+12                  312
# 45                 16.0       6.900000e+12                   12
# 46                 21.0       6.980000e+12                   16
# 47                 22.0       7.000000e+12                   31
# 48                120.0       7.079460e+12                  151
# 49                 36.0       7.150000e+12                   40
# 50                 36.0       7.300000e+12                   39
# 51                 96.0       7.750000e+12                  114
# 52                112.0       7.943280e+12                  117
# 53                 33.0       8.500000e+12                   36
# 54                131.0       8.912510e+12                  137
# 55                296.0       1.000000e+13                  438
#
#     count_fraction
# 0         0.058824
# 1         0.111111
# 2         0.043478
# 3         0.250000
# 4         0.050000
# 5         0.500000
# 6         0.277778
# 7         0.300000
# 8         0.166667
# 9         0.047619
# 10        0.117647
# 11        0.368421
# 12        0.200000
# 13        0.564516
# 14        1.000000
# 15        0.142857
# 16        0.222222
# 17        0.393939
# 18        0.666667
# 19        0.322581
# 20        0.338028
# 21        0.500000
# 22        0.466667
# 23        0.518519
# 24        0.467532
# 25        0.727273
# 26        0.666667
# 27        0.400000
# 28        0.468468
# 29        0.815789
# 30        0.650000
# 31        0.605263
# 32        0.828571
# 33        0.523810
# 34        0.923077
# 35        0.739130
# 36        0.812500
# 37        0.716667
# 38        0.928571
# 39        0.879365
# 40        1.066667
# 41        0.811594
# 42        0.911765
# 43        1.000000
# 44        0.868590
# 45        1.333333
# 46        1.312500
# 47        0.709677
# 48        0.794702
# 49        0.900000
# 50        0.923077
# 51        0.842105
# 52        0.957265
# 53        0.916667
# 54        0.956204
# 55        0.675799

# %%
t_all_bgf10_simu_events_by_energy_merged_nona.plot(x='etruth_trueenergy', y='count_fraction', marker='.',linestyle='-', color='purple')
plt.show()

# %%
#AND x_y_hough__peak_thr3__avg_line_coord_0_x > 8 AND x_y_hough__peak_thr3__avg_line_coord_0_y > 8
cond_selection_rules = '''
  AND x_y_active_pixels_num > 1750
  AND num_gtu BETWEEN 11 AND 40
  AND num_triggered_pixels >= 6
  AND (abs(gtu_y_hough__peak_thr2_avg_phi) > 0.174533 OR abs(gtu_x_hough__peak_thr2_avg_phi) > 0.174533)
  AND num_triggered_pixels < 150
  AND trigg_x_y_hough__peak_thr1__max_cluster_counts_sum_width < 20
  AND trigg_gtu_x_hough__peak_thr1__max_cluster_counts_sum_width < 41 AND trigg_gtu_y_hough__peak_thr1__max_cluster_counts_sum_width < 41
  AND x_y_hough__peak_thr1__max_cluster_counts_sum_width < 25
  AND trigg_gtu_y_hough__peak_thr2__max_cluster_counts_sum_width < 20 AND trigg_gtu_y_hough__peak_thr2__max_cluster_counts_sum_height < 20
  AND trigg_gtu_x_hough__peak_thr2__max_cluster_counts_sum_width < 20 AND trigg_gtu_x_hough__peak_thr2__max_cluster_counts_sum_height < 20
  AND gtu_y_hough__dbscan_num_clusters_above_thr1 < 4 AND gtu_x_hough__dbscan_num_clusters_above_thr1 < 4
  AND trigg_x_y_hough__dbscan_num_clusters_above_thr1 < 4
  AND ( abs(gtu_y_hough__peak_thr3_avg_phi) NOT BETWEEN 1.48353 AND 1.65806  OR  abs(gtu_x_hough__peak_thr3_avg_phi) NOT BETWEEN 1.48353 AND 1.65806 )
  AND trigg_gtu_y_hough__dbscan_num_clusters_above_thr1 < 4 AND trigg_gtu_x_hough__dbscan_num_clusters_above_thr1 < 4
  AND gtu_y_hough__peak_thr1__max_cluster_counts_sum_width < 41 AND gtu_x_hough__peak_thr1__max_cluster_counts_sum_width < 41
'''

# %%
# LESS INTERESTING
t_cond_bgf10_simu_events_by_energy_query = \
'''
SELECT COUNT(sq.count_event_id) AS count_packets, sq.etruth_trueenergy AS etruth_trueenergy 
 FROM (
  SELECT COUNT(dt1.event_id) AS count_event_id, dt1.source_file_acquisition_full, etruth_trueenergy 
  FROM simu_event_spb_proc 
  JOIN simu_event USING(simu_event_id) 
  JOIN (
   SELECT event_id, source_file_acquisition_full, packet_id
   FROM spb_processing_event_ver2
   WHERE
   source_data_type_num=5 AND 
   {cond_selection_rules}
  ) AS dt1 USING(event_id) 
  LEFT INNER JOIN spb_processing_event_ver2 AS dt2 USING(source_file_acquisition_full) 
  WHERE dt2.source_data_type_num=3 
  GROUP BY etruth_trueenergy, dt1.source_file_acquisition_full, dt1.packet_id) AS sq 
 GROUP BY etruth_trueenergy ORDER BY etruth_trueenergy;
'''.format(cond_selection_rules=cond_selection_rules)

t_cond_bgf10_simu_events_by_energy = psql.read_sql(cond_bgf10_simu_events_by_energy_query, con)

# %%
 # IMPORTANT
t_cond_bgf05_simu_events_by_energy_query = \
'''
SELECT COUNT(sq.count_event_id) AS count_packets, sq.etruth_trueenergy AS etruth_trueenergy 
 FROM (
  SELECT COUNT(dt1.event_id) AS count_event_id, dt1.source_file_acquisition_full, etruth_trueenergy 
  FROM simu_event_spb_proc 
  JOIN simu_event USING(simu_event_id) 
  JOIN (
   SELECT event_id, source_file_acquisition_full, packet_id
   FROM spb_processing_event_ver2
   WHERE
   source_data_type_num=3  
   {cond_selection_rules}
  ) AS dt1 USING(event_id) 
  JOIN spb_processing_event_ver2 AS dt2 USING(source_file_acquisition_full) 
  WHERE dt2.source_data_type_num=5
  GROUP BY etruth_trueenergy, dt1.source_file_acquisition_full, dt1.packet_id) AS sq 
 GROUP BY etruth_trueenergy ORDER BY etruth_trueenergy;
'''.format(cond_selection_rules=cond_selection_rules)

t_cond_bgf05_simu_events_by_energy = psql.read_sql(t_cond_bgf05_simu_events_by_energy_query, con)

# %%
t_cond_bgf05_simu_events_by_energy
# Out:
#     count_packets  etruth_trueenergy
# 0               1       1.412540e+12
# 1               1       1.900000e+12
# 2               1       1.995260e+12
# 3               1       2.100000e+12
# 4               2       2.238720e+12
# 5               2       2.300000e+12
# 6               2       2.350000e+12
# 7               1       2.420000e+12
# 8               1       2.500000e+12
# 9               3       2.511890e+12
# 10              4       2.800000e+12
# 11              9       2.818380e+12
# 12             23       2.875000e+12
# 13              2       2.900000e+12
# 14              2       3.000000e+12
# 15              6       3.162280e+12
# 16              8       3.250000e+12
# 17              2       3.350000e+12
# 18              8       3.500000e+12
# 19             16       3.548130e+12
# 20             15       3.700000e+12
# 21              4       3.825000e+12
# 22             12       3.940000e+12
# 23             27       3.981070e+12
# 24             11       4.000000e+12
# 25             11       4.150000e+12
# 26              4       4.300000e+12
# 27             37       4.466840e+12
# 28             18       4.600000e+12
# 29              5       4.775000e+12
# 30             50       5.011870e+12
# 31             11       5.050000e+12
# 32              7       5.250000e+12
# 33             10       5.300000e+12
# 34             12       5.460000e+12
# 35             55       5.500000e+12
# 36             55       5.623410e+12
# 37              7       5.725000e+12
# 38            197       5.950000e+12
# 39              9       6.200000e+12
# 40             67       6.309570e+12
# 41             14       6.400000e+12
# 42              7       6.675000e+12
# 43            179       6.850000e+12
# 44             11       6.900000e+12
# 45             14       6.980000e+12
# 46             12       7.000000e+12
# 47             74       7.079460e+12
# 48             18       7.150000e+12
# 49             14       7.300000e+12
# 50             78       7.750000e+12
# 51             69       7.943280e+12
# 52             27       8.500000e+12
# 53             86       8.912510e+12
# 54            238       1.000000e+13

# %%
ax_t_all_bgf05_simu_events_by_energy = t_all_bgf05_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_packets',marker='.',linestyle='-', color='blue', label="All packets bgf=0.5 and bgf=1")
#all_bgf10_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_packets',marker='.',linestyle='-', color='red', ax=ax_all_simu_events_by_energy)
t_cond_bgf05_simu_events_by_energy.plot(x='etruth_trueenergy',y='count_packets',marker='.',linestyle='-', color='green', ax=ax_t_all_bgf05_simu_events_by_energy, label="Selected packets bgf=0.5 and bgf=1")
ax_t_all_bgf05_simu_events_by_energy.set_yscale("log", nonposy='clip')
plt.show()

# %%
t_cond_bgf05_simu_events_by_energy_merged = pd.merge(t_cond_bgf05_simu_events_by_energy, t_all_bgf05_simu_events_by_energy,
                                    how='outer',
                                    suffixes=['_cond','_all'],
                                    on=['etruth_trueenergy'])
t_cond_bgf05_simu_events_by_energy_merged_nona = t_cond_bgf05_simu_events_by_energy_merged.dropna().copy()
t_cond_bgf05_simu_events_by_energy_merged_nona['count_fraction'] = t_cond_bgf05_simu_events_by_energy_merged_nona['count_packets_cond'] / t_cond_bgf05_simu_events_by_energy_merged_nona['count_packets_all']
t_cond_bgf05_simu_events_by_energy_merged_nona
# Out:
#     count_packets_cond  etruth_trueenergy  count_packets_all  count_fraction
# 0                  1.0       1.412540e+12                  1        1.000000
# 1                  1.0       1.900000e+12                  2        0.500000
# 2                  1.0       1.995260e+12                  1        1.000000
# 3                  1.0       2.100000e+12                  1        1.000000
# 4                  2.0       2.238720e+12                  2        1.000000
# 5                  2.0       2.300000e+12                  2        1.000000
# 6                  2.0       2.350000e+12                  5        0.400000
# 7                  1.0       2.420000e+12                  1        1.000000
# 8                  1.0       2.500000e+12                  1        1.000000
# 9                  3.0       2.511890e+12                  3        1.000000
# 10                 4.0       2.800000e+12                  7        0.571429
# 11                 9.0       2.818380e+12                 12        0.750000
# 12                23.0       2.875000e+12                 34        0.676471
# 13                 2.0       2.900000e+12                  2        1.000000
# 14                 2.0       3.000000e+12                  3        0.666667
# 15                 6.0       3.162280e+12                  8        0.750000
# 16                 8.0       3.250000e+12                 12        0.666667
# 17                 2.0       3.350000e+12                  7        0.285714
# 18                 8.0       3.500000e+12                 10        0.800000
# 19                16.0       3.548130e+12                 21        0.761905
# 20                15.0       3.700000e+12                 22        0.681818
# 21                 4.0       3.825000e+12                  7        0.571429
# 22                12.0       3.940000e+12                 14        0.857143
# 23                27.0       3.981070e+12                 32        0.843750
# 24                11.0       4.000000e+12                 14        0.785714
# 25                11.0       4.150000e+12                 21        0.523810
# 26                 4.0       4.300000e+12                  6        0.666667
# 27                37.0       4.466840e+12                 46        0.804348
# 28                18.0       4.600000e+12                 27        0.666667
# 29                 5.0       4.775000e+12                 10        0.500000
# 30                50.0       5.011870e+12                 63        0.793651
# 31                11.0       5.050000e+12                 21        0.523810
# 32                 7.0       5.250000e+12                 11        0.636364
# 33                10.0       5.300000e+12                 11        0.909091
# 34                12.0       5.460000e+12                 16        0.750000
# 35                55.0       5.500000e+12                 75        0.733333
# 36                55.0       5.623410e+12                 65        0.846154
# 37                 7.0       5.725000e+12                 12        0.583333
# 38               197.0       5.950000e+12                281        0.701068
# 39                 9.0       6.200000e+12                 12        0.750000
# 40                67.0       6.309570e+12                 85        0.788235
# 41                14.0       6.400000e+12                 23        0.608696
# 42                 7.0       6.675000e+12                 13        0.538462
# 43               179.0       6.850000e+12                269        0.665428
# 44                11.0       6.900000e+12                 11        1.000000
# 45                14.0       6.980000e+12                 15        0.933333
# 46                12.0       7.000000e+12                 15        0.800000
# 47                74.0       7.079460e+12                103        0.718447
# 48                18.0       7.150000e+12                 28        0.642857
# 49                14.0       7.300000e+12                 32        0.437500
# 50                78.0       7.750000e+12                120        0.650000
# 51                69.0       7.943280e+12                 89        0.775281
# 52                27.0       8.500000e+12                 29        0.931034
# 53                86.0       8.912510e+12                114        0.754386
# 54               238.0       1.000000e+13                317        0.750789

# %%
n1 = t_cond_bgf05_simu_events_by_energy_merged_nona['count_packets_cond']
n2 = t_cond_bgf05_simu_events_by_energy_merged_nona['count_packets_all']

yerrs = list( np.sqrt( ((1-(n1/n2))/n1) + (1/n2) ) ) 
#yerrs = list( np.sqrt(n1 * (1 - n1/n2))/n2 )
yerrs
# Out:
# [1.0,
#  1.0,
#  1.0,
#  1.0,
#  0.70710678118654757,
#  0.70710678118654757,
#  0.70710678118654757,
#  1.0,
#  1.0,
#  0.57735026918962573,
#  0.5,
#  0.33333333333333331,
#  0.20851441405707477,
#  0.70710678118654757,
#  0.70710678118654757,
#  0.40824829046386302,
#  0.35355339059327379,
#  0.70710678118654757,
#  0.35355339059327379,
#  0.25,
#  0.25819888974716115,
#  0.5,
#  0.28867513459481287,
#  0.19245008972987526,
#  0.30151134457776363,
#  0.30151134457776363,
#  0.5,
#  0.16439898730535729,
#  0.23570226039551584,
#  0.44721359549995793,
#  0.1414213562373095,
#  0.30151134457776363,
#  0.3779644730092272,
#  0.31622776601683794,
#  0.28867513459481287,
#  0.13483997249264842,
#  0.13483997249264842,
#  0.3779644730092272,
#  0.071247049987909636,
#  0.33333333333333331,
#  0.12216944435630522,
#  0.2672612419124244,
#  0.3779644730092272,
#  0.074743509275193576,
#  0.30151134457776363,
#  0.2672612419124244,
#  0.28867513459481287,
#  0.11624763874381927,
#  0.23570226039551584,
#  0.2672612419124244,
#  0.11322770341445958,
#  0.1203858530857692,
#  0.19245008972987526,
#  0.10783277320343841,
#  0.064820372355216441]

# %%
t_cond_bgf05_simu_events_by_energy_merged_nona.plot(x='etruth_trueenergy', y='count_fraction', yerr=yerrs, marker='.',linestyle='-', ecolor='green', linewidth=1, label='Fraction of all packets')
plt.show()
# plt.errorbar(t_cond_bgf05_simu_events_by_energy_merged_nona['etruth_trueenergy'], 
#              t_cond_bgf05_simu_events_by_energy_merged_nona['count_fraction'], yerr=yerrs, marker='.',linestyle='-', ecolor='green', linewidth=1)
# plt.show()

# %%
# simu2npy_pathanme_glob = "/home/eusobg/EUSO-SPB/SPBDATA_processed/spb_simu/posz_18000000/namefiles18000000.0A6.19999972557e+12E.txt/simu.2017-07-22-04h32m23s/simu2npy/ev_12_*signals.npy"
# simu2npy_pathanme = glob.glob(simu2npy_pathanme_glob)
# ev_frames = np.load(simu2npy_pathanme[0])
# npy_vis.visualize_frame(np.maximum.reduce(ev_frames))
